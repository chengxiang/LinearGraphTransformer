# %% [markdown]
# Implementation of ZINC experiment for the paper
# [Graph Transformers Dream of Electric Flow](https://arxiv.org/abs/2410.16699)
# Cheng, Carin, Sra 2025
#
# Graph Transformer implementation is based on
# [A generalization of transformer networks to graphs](https://arxiv.org/pdf/2012.09699.pdf)
# Dwivedi, Bresson, 2020
#
#
# Code for base Graph Transformer is taken from https://github.com/xbresson/CS6208_2023

# %%
#import os
#os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
# Libraries
import pickle
from utils import Dictionary, MoleculeDataset, MoleculeDGL, Molecule
import dgl
from dgl.data import MiniGCDataset
import dgl.function as fn
import matplotlib.pyplot as plt
import torch
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torch.nn as nn
import time
import networkx as nx
from utils import compute_ncut
import os, datetime
from itertools import chain
import torch.autograd.profiler as profiler


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.cuda.set_device(0)

# %%
# Select dataset
dataset_name = 'ZINC'; data_folder_pytorch = 'ZINC_pytorch_clean/'; data_folder_dgl = 'ZINC_dgl_clean/'
#dataset_name = 'QM9'; data_folder_pytorch = '../labs_lecture09/QM9_pytorch/'; data_folder_dgl = '../labs_lecture09/QM9_dgl/'

# Load the number of atom and bond types 
with open(data_folder_pytorch + "atom_dict.pkl" ,"rb") as f: num_atom_type = len(pickle.load(f))
with open(data_folder_pytorch + "bond_dict.pkl" ,"rb") as f: num_bond_type = len(pickle.load(f))
print(num_atom_type)
print(num_bond_type)

# Load the DGL datasets
datasets_zinc = MoleculeDataset(dataset_name, data_folder_dgl)
trainset, valset, testset = datasets_zinc.train, datasets_zinc.val, datasets_zinc.test
print(len(trainset))
print(len(valset))
print(len(testset))
idx = 0
print(trainset[0])
max_nodes = max(max([g[0].num_nodes() for g in trainset]), max([g[0].num_nodes() for g in testset]), max([g[0].num_nodes() for g in valset]),)
max_edges = max(max([g[0].num_edges() for g in trainset]), max([g[0].num_edges() for g in testset]), max([g[0].num_edges() for g in valset]),)
print('max nodes', max_nodes)
print('max edges', max_edges)

def preprocess_B(trainset, max_n=max_nodes, max_e = int(max_edges/2)):
    B_trainset = torch.zeros(len(trainset), max_n, max_e).to(device)
    e_feat_mat = torch.zeros(len(trainset), max_e)
    n_feat_mat = torch.zeros(len(trainset), max_n)
    aug_trainset = [(i, (g[0].to(device), g[1].to(device))) for (i,g) in enumerate(trainset)]
    for t in aug_trainset:
        i = t[0]
        g = t[1][0]
        n_e = g.num_edges()
        n_n = g.num_nodes()
        B, keep_inds, discard_inds = remove_bi(g.inc('both').to_dense().to(device))
        B_trainset[i,0:n_n,0:B.shape[1]] = B#/(B.norm(p=1,dim=1)[:,None]**0.5)
        e_feat_mat[i,0:B.shape[1]] = g.edata['feat'][keep_inds.int()].to(device)
        n_feat_mat[i,0:g.ndata['feat'].shape[0]] = g.ndata['feat'].to(device)
        assert (g.edata['feat'][keep_inds.int()] - g.edata['feat'][discard_inds.int()]).float().norm()==0
    return B_trainset, aug_trainset, e_feat_mat, n_feat_mat

def remove_bi(B):
    indices = (torch.einsum('ij,ik->jk',(B,B)) == -2).nonzero(as_tuple=False)
    indices_list = [tuple(idx.tolist()) for idx in indices]
    indices_list = [(min(a[0],a[1]), max(a[0],a[1])) for a in indices_list]
    sorted_indices = sorted(indices_list)
    #print(sorted_indices)
    keep_inds = torch.tensor(sorted_indices)[0:-1:2][:,0]
    discard_inds = torch.tensor(sorted_indices)[0:-1:2][:,1]
    return B[:,keep_inds], keep_inds, discard_inds

B_trainset, aug_trainset, e_feat_train, n_feat_train = preprocess_B(trainset)
B_testset, aug_testset, e_feat_test, n_feat_test = preprocess_B(testset)
B_valset, aug_valset, e_feat_val, n_feat_val = preprocess_B(valset)
# Out:
# 21
# 4
# Loading datasets ZINC_dgl...
# train, test, val sizes : 20000 5000 2000
# Time: 21.1780s
# 20000
# 2000
# 5000
# (Graph(num_nodes=18, num_edges=36,
#       ndata_schemes={'feat': Scheme(shape=(), dtype=torch.int64)}
#       edata_schemes={'feat': Scheme(shape=(), dtype=torch.int64)}), tensor([0.4812]))
# max nodes 37
# max edges 84

# %% [markdown]
# # Add positional encoding feature

# %%
pos_enc_dim = 6 # dimension of PE, ZINCx

# Positional encoding as Laplacian eigenv_feat_feat_feat_feat_feat_feat_feat_feat_feat_feat_feat_featectors
def LapEig_positional_encoding(g, pos_enc_dim):
    Adj = g.adj().to_dense() # Adjacency matrix
    Dn = ( g.in_degrees()** -0.5 ).diag() # Inverse and sqrt of degree matrix
    Lap = torch.eye(g.number_of_nodes()).to(device) - Dn.matmul(Adj).matmul(Dn) # Laplacian operator
    EigVal, EigVec = torch.linalg.eig(Lap) # Compute full EVD
    EigVal, EigVec = EigVal.real, EigVec.real # make eig real
    EigVec = EigVec[:, EigVal.argsort()] # sort in increasing order of eigenvalues
    EigVec = EigVec[:,1:pos_enc_dim+1] # select the first non-trivial "pos_enc_dim" eigenvector
    if EigVec.shape[1] < pos_enc_dim:
        EigVec = torch.cat((EigVec, torch.zeros((EigVec.shape[0], pos_enc_dim-EigVec.shape[1])).to(device)), dim=1)
    return EigVec

# Add node and edge features to graphs
#pos_enc_dim = 3 # dimension of PE, QM9
def add_node_edge_features(dataset):
    for (_, (graph,_)) in dataset:
        graph.ndata['pos_enc'] = LapEig_positional_encoding(graph, pos_enc_dim) # node positional encoding feature 
    return dataset

# Generate graph datasets
aug_trainset = add_node_edge_features(aug_trainset)
aug_testset = add_node_edge_features(aug_testset)
aug_valset = add_node_edge_features(aug_valset)

# %%
max_nodes = max(max([g[1][0].num_nodes() for g in aug_trainset]), max([g[1][0].num_nodes() for g in aug_testset]), max([g[1][0].num_nodes() for g in aug_valset]),)
max_edges = max(max([g[1][0].num_edges() for g in aug_trainset]), max([g[1][0].num_edges() for g in aug_testset]), max([g[1][0].num_edges() for g in aug_valset]),)

# %%
# collate function prepares a batch of graphs, labels and other graph features (if needed)
def collate(samples):
    # Input sample is a list of pairs (idx, (graph, label))
    (indices, samples) = map(list, zip(*samples))
    graphs, labels = map(list, zip(*samples))
    batch_graphs = dgl.batch(graphs)    # batch of graphs
    batch_labels = torch.stack(labels)  # batch of labels (here chemical target)
    return batch_graphs, batch_labels, indices

# %%
# Define a two-layer MLP for regression 
class MLP_layer(nn.Module): 
    
    def __init__(self, input_dim, hidden_dim): 
        super(MLP_layer, self).__init__()
        self.linear1 = nn.Linear( input_dim, hidden_dim, bias=True )
        self.linear2 = nn.Linear( hidden_dim, 1, bias=True )
        
    def forward(self, x):
        y = self.linear2(torch.relu(self.linear1(x)))
        return y

        
# class graph multi head attention layer  
class graph_MHA_layer(nn.Module): # MHA = Multi Head Attention
    
    def __init__(self, hidden_dim, head_hidden_dim, num_heads): # hidden_dim = d
        super().__init__()
        self.head_hidden_dim = head_hidden_dim # head_hidden_dim = d' = d/K
        self.num_heads = num_heads # number of heads = K
        self.WQ = nn.Linear(hidden_dim, head_hidden_dim * num_heads, bias=True) # define K x W matrix of size=(d',d')
        self.WK = nn.Linear(hidden_dim, head_hidden_dim * num_heads, bias=True)
        self.WV = nn.Linear(hidden_dim, head_hidden_dim * num_heads, bias=True)
        self.WE = nn.Linear(hidden_dim, head_hidden_dim * num_heads, bias=True)
        self.WF = nn.Linear(hidden_dim, head_hidden_dim * num_heads, bias=True)
        self.WG = nn.Linear(hidden_dim, head_hidden_dim * num_heads, bias=True)
        
    # Step 1 of message-passing with DGL: 
    #   Node feature and edge features are passed along edges (src/j => dst/i) 
    def message_func(self, edges): 
        # Compute bi-linear products with edge feature : q_i^T * diag(e_ij) * k_j 
        # You may use "edges.dst[] for i, edges.src[] for j, edges.data[] form ij" 
        qikj = (edges.src['K'] * edges.data['E'] * edges.dst['Q']).sum(dim=2).unsqueeze(2) # size=(E,K,1), edges.src/dst/data[].size=(E,K,d')
        expij = torch.exp( (qikj / torch.sqrt(torch.tensor(self.head_hidden_dim))).clamp(-5, 5) ) # exp_ij = exp( clamp(q_i^T * k_j / sqrt(d')) ), size=(E,K,1)
        vj = edges.src['V'] # size=(E,K,d')
        # Compute edge feature : q_i^T * diag(e_ij) * k_j
        eij = edges.src['K'] * edges.data['E'] * edges.dst['Q'] / torch.sqrt(torch.tensor(self.head_hidden_dim)) # e_ij = q_i^T * diag(E_ij) * k_j / sqrt(d'), size=(E,K,d')
        edges.data['e'] = eij # update edge feature 
        return {'expij' : expij, 'vj' : vj} 
    
    # Step 2 of message-passing with DGL: 
    #   Reduce function collects all messages={hj, eij} sent to node dst/i with Step 1
    #                   and sum/mean over the graph neigbors j in Ni
    def reduce_func(self, nodes):
        expij = nodes.mailbox['expij'] # size=(N,|Nj|,K,1), |Nj|=num_neighbors
        vj = nodes.mailbox['vj'] # size=(N,|Nj|,K,d')
        numerator = torch.sum( expij * vj, dim=1 ) # sum_j exp_ij . v_j, size=(N,K,d')
        denominator = torch.sum( expij, dim=1 ) # sum_j' exp_ij', size=(N,K,1)
        h = numerator / denominator # h_i = sum_j score_ij . v_j , where score_ij = exp_ij / sum_j' exp_ij', size=(N,K,d')
        return {'h' : h} 
    
    def forward(self, g, h, e):
        Q = self.WQ(h) # size=(N, d)
                       # computational trick to compute quickly K linear transformations h_k.WQ of size=(N, d')
                       # first compute linear transformation h.WQ of size=(N, d)
                       # then reshape h.WQ of size=(N, K, d'=d/K)
        K = self.WK(h) # size=(N, d)
        V = self.WV(h) # size=(N, d)
        E = self.WE(e) # size=(E, d)
        F = self.WF(h) # size=(N, d)
        G = self.WG(h) # size=(N, d)
        g.ndata['Q'] = Q.view(-1, self.num_heads, self.head_hidden_dim) # size=(N, K, d'=d/K)
        g.ndata['K'] = K.view(-1, self.num_heads, self.head_hidden_dim) # size=(N, K, d'=d/K)
        g.ndata['V'] = V.view(-1, self.num_heads, self.head_hidden_dim) # size=(N, K, d'=d/K)
        g.edata['E'] = E.view(-1, self.num_heads, self.head_hidden_dim) # size=(E, K, d'=d/K)
        g.ndata['F'] = F.view(-1, self.num_heads, self.head_hidden_dim) # size=(N, K, d'=d/K)
        g.ndata['G'] = G.view(-1, self.num_heads, self.head_hidden_dim) # size=(N, K, d'=d/K)
        g.update_all(self.message_func, self.reduce_func) # compute with DGL the graph MHA 
        gMHA = g.ndata['h'] # size=(N, K, d'=d/K)
        gMHE = g.edata['e'] # size=(E, K, d'=d/K)
        return gMHA, gMHE
    
    
# class GraphTransformer layer  
class GraphTransformer_layer(nn.Module):
    
    def __init__(self, hidden_dim, num_heads, norm, dropout=0.0):
        super().__init__()
        self.hidden_dim = hidden_dim # hidden_dim = d
        self.num_heads = num_heads # number of heads = K
        self.dropout = dropout # dropout value
        self.gMHA = graph_MHA_layer(hidden_dim, hidden_dim//num_heads, num_heads) # graph MHA layer
        self.WO = nn.Linear(hidden_dim, hidden_dim) # LL
        self.WOe = nn.Linear(hidden_dim, hidden_dim) # LL
        self.norm = norm # type of layer normalization
        if self.norm == 'LN': # layer normalization
            self.layer_norm1 = nn.LayerNorm(hidden_dim)
            self.layer_norm2 = nn.LayerNorm(hidden_dim)
            self.layer_norm1e = nn.LayerNorm(hidden_dim)
            self.layer_norm2e = nn.LayerNorm(hidden_dim)
        elif self.norm == 'BN': # batch normalization
            self.layer_norm1 = nn.BatchNorm1d(hidden_dim)
            self.layer_norm2 = nn.BatchNorm1d(hidden_dim)
            self.layer_norm1e = nn.BatchNorm1d(hidden_dim)
            self.layer_norm2e = nn.BatchNorm1d(hidden_dim)
        self.linear1 = nn.Linear(hidden_dim, hidden_dim) # LL1 for MLP
        self.linear2 = nn.Linear(hidden_dim, hidden_dim) # LL2 for MLP
        self.linear1e = nn.Linear(hidden_dim, hidden_dim) # LL1 for MLP
        self.linear2e = nn.Linear(hidden_dim, hidden_dim) # LL2 for MLP
        
    def forward(self, g, h, e): 
        
        # Self-attention layer
        h_rc = h # size=(N,d), V=num_nodes, for residual connection
        e_rc = e
        h_MHA, e_MHE = self.gMHA(g, h, e) # MHA, size=(N, K, d'=d/K)
        h_MHA = h_MHA.view(-1, self.hidden_dim) # size=(N, d)
        e_MHE = e_MHE.view(-1, self.hidden_dim) # size=(N, d)
        h_MHA = F.dropout(h_MHA, self.dropout, training=self.training) # dropout, size=(N, d)
        e_MHE = F.dropout(e_MHE, self.dropout, training=self.training) # dropout, size=(N, d)
        h_MHA = self.WO(h_MHA) # LL, size=(N, d)
        e_MHE = self.WOe(e_MHE) # LL, size=(N, d)
        h = h_rc + h_MHA # residual connection, size=(N, d)
        e = e_rc + e_MHE # residual connection, size=(N, d)
        h = self.layer_norm1(h) # layer normalization, size=(N, d)
        e = self.layer_norm1e(e) # layer normalization, size=(N, d)
        
        # Fully-connected layer
        h_rc = h # for residual connection, size=(N, d)
        e_rc = e # for residual connection, size=(N, d)
        h_MLP = self.linear1(h) # LL, size=(H, d)
        e_MLP = self.linear1e(e) # LL, size=(H, d)
        h_MLP = torch.relu(h_MLP) # size=(N, d)
        e_MLP = torch.relu(e_MLP) # size=(N, d)
        h_MLP = F.dropout(h_MLP, self.dropout, training=self.training) # dropout, size=(N, d)
        e_MLP = F.dropout(e_MLP, self.dropout, training=self.training) # dropout, size=(N, d)
        h_MLP = self.linear2(h_MLP) # LL, size=(N, d)
        e_MLP = self.linear2e(e_MLP) # LL, size=(N, d)
        h = h_rc + h_MLP # residual connection, size=(N, d)
        e = e_rc + e_MLP # residual connection, size=(N, d)
        h = self.layer_norm2(h) # layer normalization, size=(N, d)
        e = self.layer_norm2e(e) # layer normalization, size=(N, d)
        
        return h, e
    
    
# class Graph Transformer network
class GraphTransformer_net(nn.Module):
    
    def __init__(self, net_parameters):
        super(GraphTransformer_net, self).__init__()
        input_dim = net_parameters['input_dim']
        pos_enc_dim = net_parameters['pos_enc_dim']
        hidden_dim = net_parameters['hidden_dim']
        num_heads = net_parameters['num_heads']
        norm = net_parameters['norm'] 
        L = net_parameters['L']
        self.embedding_h = nn.Embedding(num_atom_type, hidden_dim)
        self.embedding_e = nn.Embedding(num_bond_type, hidden_dim)
        self.embedding_pe = nn.Linear(pos_enc_dim, hidden_dim)
        self.GraphTransformer_layers = nn.ModuleList([ GraphTransformer_layer(hidden_dim, num_heads, norm) for _ in range(L) ]) 
        self.MLP_layer = MLP_layer(hidden_dim, 1)
        
    def forward(self, g, h, pe, e):
        
        # input node embedding
        h = self.embedding_h(h) # size=(num_nodes, hidden_dim)
        
        # if PE used
        h = h + self.embedding_pe(pe) # size=(num_nodes, hidden_dim)
        
        # input edge embedding
        e = self.embedding_e(e) # size=(num_edges, hidden_dim)
        
        # graph convnet layers
        for GT_layer in self.GraphTransformer_layers:
            h, e = GT_layer(g, h, e) # size=(num_nodes, hidden_dim)
        
        # MLP classifier
        g.ndata['h'] = h
        y = dgl.mean_nodes(g,'h') # DGL mean function over the neighbors, size=(num_graphs, hidden_dim)
        y = self.MLP_layer(y) # size=(num_graphs, num_classes)    
        return y    
    
    def loss(self, y_scores, y_labels):
        loss = nn.L1Loss()(y_scores, y_labels)
        return loss        
        

# Instantiate one network (testing)
net_parameters = {}
net_parameters['input_dim'] = 1
net_parameters['pos_enc_dim'] = pos_enc_dim
net_parameters['hidden_dim'] = 128
net_parameters['num_heads'] = 8
net_parameters['norm'] = 'BN' 
net_parameters['L'] = 4
net = GraphTransformer_net(net_parameters)
print(net)
# Out:
# GraphTransformer_net(
#   (embedding_h): Embedding(21, 128)
#   (embedding_e): Embedding(4, 128)
#   (embedding_pe): Linear(in_features=6, out_features=128, bias=True)
#   (GraphTransformer_layers): ModuleList(
#     (0-3): 4 x GraphTransformer_layer(
#       (gMHA): graph_MHA_layer(
#         (WQ): Linear(in_features=128, out_features=128, bias=True)
#         (WK): Linear(in_features=128, out_features=128, bias=True)
#         (WV): Linear(in_features=128, out_features=128, bias=True)
#         (WE): Linear(in_features=128, out_features=128, bias=True)
#         (WF): Linear(in_features=128, out_features=128, bias=True)
#         (WG): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (WO): Linear(in_features=128, out_features=128, bias=True)
#       (WOe): Linear(in_features=128, out_features=128, bias=True)
#       (layer_norm1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (layer_norm2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (layer_norm1e): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (layer_norm2e): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (linear1): Linear(in_features=128, out_features=128, bias=True)
#       (linear2): Linear(in_features=128, out_features=128, bias=True)
#       (linear1e): Linear(in_features=128, out_features=128, bias=True)
#       (linear2e): Linear(in_features=128, out_features=128, bias=True)
#     )
#   )
#   (MLP_layer): MLP_layer(
#     (linear1): Linear(in_features=128, out_features=1, bias=True)
#     (linear2): Linear(in_features=1, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# # Train the network

# %%
import numpy as np

n = max_nodes
d = int(max_edges/2)
batch_size = 200
pos_enc_dim = 6
my_pos_enc_dim = 3
pe_norm = 0


def inverse_permutation(perm):
    inv = torch.empty_like(perm)
    inv[perm] = torch.arange(perm.size(0), device=perm.device)
    return inv

def run_one_epoch(net, data_loader, model, B_all, dataset, train=True):
    lst_norm_p = []
    lst_model_norm_p = []
    if train:
        net.train() # during training
        #model.train()
    else:
        net.eval()  # during inference/test
        #model.eval()
    epoch_loss = 0
    nb_data = 0
    for iter, (batch_graphs, batch_labels, indices) in enumerate(data_loader):
        batch_pe = batch_graphs.ndata['pos_enc'].to(device)* ( 2 * torch.randint(low=0, high=2, size=(1,pos_enc_dim)).float().to(device) - 1.0 )
        pe_norm = (batch_pe.norm(p=2,dim=0)[None,:].mean()/(len(indices)**0.5)).item()
        batch_x = batch_graphs.ndata['feat'].to(device)
        batch_e = batch_graphs.edata['feat'].to(device)

        batch_labels = batch_labels.to(device)
        batch_graphs = batch_graphs.to(device)
        batch_x = batch_x.to(device)
        batch_labels = batch_labels.to(device)
        
        batch_scores = net.forward(batch_graphs.to(device), batch_x, batch_pe, batch_e)
        loss = net.loss(batch_scores, batch_labels)

        if train: # during training, run backpropagation
            optimizer.zero_grad()
            #optimizer_model.zero_grad()
            loss.backward()
            
            norm_p = clip((net.parameters(), ), clip_r = clip_r)
            lst_norm_p.append(norm_p)
            #lst_model_norm_p.append(model_norm_p)
            
            optimizer.step()
            #optimizer_model.step()
        epoch_loss += loss.detach().item()
        nb_data += batch_labels.size(0)
        
    if train:
        print('total: [{:.4f}, {:.4f}, {:.4f}, {:.4f}], count={}'
                  .format(np.percentile(lst_norm_p, 25), np.percentile(lst_norm_p, 50), 
                          np.percentile(lst_norm_p, 75), np.percentile(lst_norm_p, 100), 
                          len([num for num in lst_norm_p if num > clip_r])))
    epoch_loss /= (iter + 1)
    return epoch_loss
    


def clip(model_params, clip_r = None):
    norm_p=None
    norm_p = 1e-11
    for p in model_params[0]:
        if p.grad is not None:
            norm_p += p.grad.norm().item()**2
    net_norm_p = norm_p**0.5
    #for p in model_params[1]:
    #    if p.grad is not None:
    #        norm_p += p.grad.norm().item()**2
    #norm_p = norm_p**0.5
    
    model_norm_p = (norm_p**2 - net_norm_p**2)**0.5
    if norm_p > clip_r:
        for p in model_params[0]:
            if p.grad is not None:
                p.grad.mul_(clip_r/norm_p)
    #    for p in model_params[1]:
    #        if p.grad is not None:
    #            p.grad.mul_(clip_r/norm_p)
    return norm_p#, model_norm_p
# set net params
net_parameters = {}
net_parameters['input_dim'] = 1
net_parameters['pos_enc_dim'] = pos_enc_dim
net_parameters['hidden_dim'] = 128
net_parameters['num_heads'] = 8
net_parameters['norm'] = 'BN' 
net_parameters['L'] = 4

num_e_f=1
num_n_f=1
phi_dim = 8
clip_r = 10
print('clip_r: {}'.format(clip_r))

# dataset loaders
train_loader = DataLoader(aug_trainset, batch_size=batch_size, shuffle=True, collate_fn=collate)
test_loader = DataLoader(aug_testset, batch_size=batch_size, shuffle=False, collate_fn=collate)
val_loader = DataLoader(aug_valset, batch_size=batch_size, shuffle=False, drop_last=False, collate_fn=collate)

run_seeds = [1]

best_val_loss = 100
best_net_dict = None

for seed in run_seeds:
    hist_list=[]
    print('choosing best initialization')
    best_net = GraphTransformer_net(net_parameters)
    best_net.to(device)
    best_train_loss = 100
    best_val_loss = 100

    for s in range(0,10):
        torch.manual_seed(seed*10+s)
        dgl.seed(seed*10+s)
        torch.cuda.manual_seed(seed*10+s)
        #actually does nothing I think??
        net = GraphTransformer_net(net_parameters)
        #model = Transformer_Z(pos_enc_dim, 3, 1, n, d, 0.1, num_e_f = num_e_f, num_n_f = num_n_f, normalize=True, phi_dim=phi_dim).to(device)
        
        net.to(device)
        #model.to(device)
        #model.load_state_dict(torch.load('8_phi_dim_1h1f_3_layer_3x_no_norm_attn_norm'))
        optimizer = torch.optim.Adam(chain(net.parameters()), lr=0.001)
        #optimizer_model = torch.optim.Adam(chain(model.parameters()), lr=0.01)
    
        #run 1 epoch and check train loss
        start = time.time()
        epoch_train_loss = run_one_epoch(net, train_loader, None, B_trainset, aug_trainset, True)
        epoch_val_loss = run_one_epoch(net, val_loader, None, B_valset, aug_valset, False)  
        print('Seed {}, time {:.4f}, train_loss: {:.4f}, val_loss: {:.4f}, s_norm: {:.4f}'
              .format(s, time.time()-start, epoch_train_loss, epoch_val_loss, 0))
        if (epoch_val_loss < best_val_loss):
            print('improving val loss to {}'.format(epoch_val_loss))
            best_train_loss = epoch_train_loss
            best_val_loss = epoch_val_loss
            best_net.load_state_dict(net.state_dict())
    
    print('Using initialization with train = {:.4f} and val = {:.4f}'.format(best_train_loss, best_val_loss))
    
    #load best model
    net.load_state_dict(best_net.state_dict())
    #model.load_state_dict(best_model.state_dict())
    optimizer = torch.optim.Adam(chain(net.parameters()), lr=0.001)
    #optimizer_model = torch.optim.Adam(chain(model.parameters()), lr=0.01)
    
    del best_net
    
    # initialize net and model
    print('gradual anneal')
    start = time.time()
    for epoch in range(2001):
        optimizer.param_groups[0]['lr'] = 0.001 * 2**(-epoch/800)
        
        epoch_train_loss = run_one_epoch(net, train_loader, None, B_trainset, aug_trainset, True)
        with torch.no_grad(): 
            epoch_test_loss = run_one_epoch(net, test_loader, None, B_testset, aug_testset, False)
            epoch_val_loss = run_one_epoch(net, val_loader, None, B_valset, aug_valset, False)  
        print('Epoch {}, time {:.4f}, train_loss: {:.4f}, test_loss: {:.4f}, val_loss: {:.4f}, s_norm: {:.4f}, pe_norm: {}'.format(epoch, time.time()-start, epoch_train_loss, epoch_test_loss, epoch_val_loss, 0, pe_norm))
        hist_list.append((epoch_train_loss, epoch_test_loss, epoch_val_loss))
        if epoch_val_loss < best_val_loss:
            best_net_dict = net.state_dict().copy()
            best_val_loss = epoch_val_loss
        if epoch%100==0:
            torch.save((net.state_dict(),), 'zinc_models/baseline_{}_epoch_{}.pth'.format(seed, epoch))
            torch.save((best_net_dict,), 'zinc_models/baseline_{}_best.pth'.format(seed))

    torch.save((best_net_dict,), 'zinc_models/baseline_{}_best.pth'.format(seed))
    loss_dict = torch.load('zinc_models/loss_dict.pth')
    loss_dict['baseline_'+str(seed)] = hist_list
    torch.save(loss_dict, 'zinc_models/loss_dict.pth')
# Out:
# clip_r: 10
# choosing best initialization
# total: [0.2787, 0.4452, 0.8094, 2.9136], count=0
# Seed 0, time 19.0191, train_loss: 0.8855, val_loss: 0.7767, s_norm: 0.0000
# improving val loss to 0.7767419159412384
# total: [0.1836, 0.2506, 0.3456, 0.8198], count=0
# Seed 1, time 10.5910, train_loss: 1.2317, val_loss: 1.4156, s_norm: 0.0000
# total: [1.4067, 3.0242, 4.5174, 10.4985], count=1
# Seed 2, time 9.8231, train_loss: 1.2498, val_loss: 1.0787, s_norm: 0.0000
# total: [0.4730, 0.5334, 0.6331, 1.4405], count=0
# Seed 3, time 10.3602, train_loss: 1.4701, val_loss: 1.4374, s_norm: 0.0000
# total: [0.3349, 0.4905, 0.7280, 1.8376], count=0
# Seed 4, time 10.4851, train_loss: 1.1102, val_loss: 1.0305, s_norm: 0.0000
# total: [0.3273, 0.4206, 0.5850, 1.2805], count=0
# Seed 5, time 10.6164, train_loss: 1.1833, val_loss: 1.1421, s_norm: 0.0000
# total: [0.5570, 0.8260, 1.2079, 3.9189], count=0
# Seed 6, time 9.9488, train_loss: 1.7341, val_loss: 1.6666, s_norm: 0.0000
# total: [0.5209, 0.9305, 1.5192, 4.9789], count=0
# Seed 7, time 4.8322, train_loss: 1.4877, val_loss: 1.4038, s_norm: 0.0000
# total: [0.4365, 0.5164, 0.6365, 1.3672], count=0
# Seed 8, time 4.9044, train_loss: 1.4218, val_loss: 1.4587, s_norm: 0.0000
# total: [0.2741, 0.5191, 0.8499, 4.2348], count=0
# Seed 9, time 4.9548, train_loss: 0.9181, val_loss: 0.8442, s_norm: 0.0000
# Using initialization with train = 0.8855 and val = 0.7767
# gradual anneal
# total: [0.2922, 0.4799, 0.7631, 2.7942], count=0
# Epoch 0, time 5.8225, train_loss: 0.7553, test_loss: 0.8054, val_loss: 0.7848, s_norm: 0.0000, pe_norm: 0
# total: [0.3300, 0.5798, 0.9821, 3.2157], count=0
# Epoch 1, time 11.3157, train_loss: 0.7046, test_loss: 0.7798, val_loss: 0.7830, s_norm: 0.0000, pe_norm: 0
# total: [0.3032, 0.6514, 1.0874, 3.0248], count=0
# Epoch 2, time 16.8221, train_loss: 0.6742, test_loss: 0.6573, val_loss: 0.6588, s_norm: 0.0000, pe_norm: 0
# total: [0.2613, 0.4934, 1.2182, 3.5655], count=0
# Epoch 3, time 22.1820, train_loss: 0.6464, test_loss: 0.6512, val_loss: 0.6514, s_norm: 0.0000, pe_norm: 0
# total: [0.2968, 0.6090, 1.0370, 3.2027], count=0
# Epoch 4, time 27.6933, train_loss: 0.6175, test_loss: 0.6530, val_loss: 0.6460, s_norm: 0.0000, pe_norm: 0
# total: [0.4251, 0.7145, 1.1182, 3.9616], count=0
# Epoch 5, time 33.0627, train_loss: 0.6122, test_loss: 0.6791, val_loss: 0.6735, s_norm: 0.0000, pe_norm: 0
# total: [0.2908, 0.5314, 1.0057, 4.1410], count=0
# Epoch 6, time 38.5027, train_loss: 0.5860, test_loss: 0.6539, val_loss: 0.6461, s_norm: 0.0000, pe_norm: 0
# total: [0.3933, 0.6397, 1.3079, 4.5832], count=0
# Epoch 7, time 43.9163, train_loss: 0.5682, test_loss: 0.6524, val_loss: 0.6506, s_norm: 0.0000, pe_norm: 0
# total: [0.2754, 0.5311, 0.8776, 3.8783], count=0
# Epoch 8, time 49.4208, train_loss: 0.5503, test_loss: 0.6126, val_loss: 0.6130, s_norm: 0.0000, pe_norm: 0
# total: [0.3529, 0.6013, 1.4143, 3.3265], count=0
# Epoch 9, time 54.8440, train_loss: 0.5477, test_loss: 0.5568, val_loss: 0.5600, s_norm: 0.0000, pe_norm: 0
# total: [0.3285, 0.6428, 1.2770, 5.6181], count=0
# Epoch 10, time 60.3767, train_loss: 0.5387, test_loss: 0.5307, val_loss: 0.5320, s_norm: 0.0000, pe_norm: 0
# total: [0.3648, 0.7923, 1.4438, 4.1634], count=0
# Epoch 11, time 65.7711, train_loss: 0.5245, test_loss: 0.5330, val_loss: 0.5245, s_norm: 0.0000, pe_norm: 0
# total: [0.3613, 0.7742, 1.4044, 5.1501], count=0
# Epoch 12, time 71.2691, train_loss: 0.5104, test_loss: 0.5172, val_loss: 0.5135, s_norm: 0.0000, pe_norm: 0
# total: [0.4121, 0.8002, 1.6251, 6.8367], count=0
# Epoch 13, time 76.6846, train_loss: 0.4978, test_loss: 0.4946, val_loss: 0.4978, s_norm: 0.0000, pe_norm: 0
# total: [0.3894, 0.8268, 1.6490, 3.8081], count=0
# Epoch 14, time 82.1246, train_loss: 0.4908, test_loss: 0.4770, val_loss: 0.4793, s_norm: 0.0000, pe_norm: 0
# total: [0.3831, 0.7634, 1.5224, 5.0195], count=0
# Epoch 15, time 87.5014, train_loss: 0.4828, test_loss: 0.5695, val_loss: 0.5682, s_norm: 0.0000, pe_norm: 0
# total: [0.4513, 0.7870, 1.4589, 6.0231], count=0
# Epoch 16, time 92.9093, train_loss: 0.4779, test_loss: 0.8036, val_loss: 0.8137, s_norm: 0.0000, pe_norm: 0
# total: [0.4798, 0.8244, 1.4572, 4.2744], count=0
# Epoch 17, time 98.2573, train_loss: 0.4752, test_loss: 0.4734, val_loss: 0.4785, s_norm: 0.0000, pe_norm: 0
# total: [0.3456, 0.7552, 1.5076, 5.2523], count=0
# Epoch 18, time 103.6919, train_loss: 0.4650, test_loss: 0.4555, val_loss: 0.4597, s_norm: 0.0000, pe_norm: 0
# total: [0.4412, 0.7966, 1.5233, 5.6521], count=0
# Epoch 19, time 109.1562, train_loss: 0.4588, test_loss: 0.4823, val_loss: 0.4845, s_norm: 0.0000, pe_norm: 0
# total: [0.3591, 0.7272, 1.6678, 4.7836], count=0
# Epoch 20, time 114.6084, train_loss: 0.4494, test_loss: 0.4813, val_loss: 0.4789, s_norm: 0.0000, pe_norm: 0
# total: [0.3828, 0.8324, 1.7269, 6.5073], count=0
# Epoch 21, time 119.9514, train_loss: 0.4503, test_loss: 0.4339, val_loss: 0.4351, s_norm: 0.0000, pe_norm: 0
# total: [0.4496, 0.8665, 2.1580, 5.9802], count=0
# Epoch 22, time 125.3751, train_loss: 0.4457, test_loss: 0.4857, val_loss: 0.4916, s_norm: 0.0000, pe_norm: 0
# total: [0.4158, 1.0155, 2.1559, 9.0055], count=0
# Epoch 23, time 130.8048, train_loss: 0.4487, test_loss: 0.4750, val_loss: 0.4714, s_norm: 0.0000, pe_norm: 0
# total: [0.4242, 0.9205, 1.7315, 5.5853], count=0
# Epoch 24, time 136.1006, train_loss: 0.4350, test_loss: 0.4627, val_loss: 0.4693, s_norm: 0.0000, pe_norm: 0
# total: [0.4277, 0.9125, 1.8189, 5.7872], count=0
# Epoch 25, time 141.5728, train_loss: 0.4353, test_loss: 0.4669, val_loss: 0.4700, s_norm: 0.0000, pe_norm: 0
# total: [0.4789, 0.9712, 2.2166, 5.7195], count=0
# Epoch 26, time 146.9157, train_loss: 0.4300, test_loss: 0.4800, val_loss: 0.4849, s_norm: 0.0000, pe_norm: 0
# total: [0.4675, 0.9675, 2.2763, 7.3688], count=0
# Epoch 27, time 152.4190, train_loss: 0.4327, test_loss: 0.5477, val_loss: 0.5559, s_norm: 0.0000, pe_norm: 0
# total: [0.4517, 0.9747, 2.2913, 6.9607], count=0
# Epoch 28, time 157.7506, train_loss: 0.4243, test_loss: 0.5522, val_loss: 0.5625, s_norm: 0.0000, pe_norm: 0
# total: [0.4701, 0.9464, 1.8312, 7.0884], count=0
# Epoch 29, time 163.2179, train_loss: 0.4240, test_loss: 0.4106, val_loss: 0.4200, s_norm: 0.0000, pe_norm: 0
# total: [0.5952, 1.0937, 2.0605, 6.6481], count=0
# Epoch 30, time 168.6095, train_loss: 0.4246, test_loss: 0.5121, val_loss: 0.5129, s_norm: 0.0000, pe_norm: 0
# total: [0.4312, 0.7751, 1.8514, 6.2529], count=0
# Epoch 31, time 174.0921, train_loss: 0.4161, test_loss: 0.4362, val_loss: 0.4288, s_norm: 0.0000, pe_norm: 0
# total: [0.4940, 1.4307, 2.4794, 6.5882], count=0
# Epoch 32, time 179.4588, train_loss: 0.4166, test_loss: 0.5193, val_loss: 0.5259, s_norm: 0.0000, pe_norm: 0
# total: [0.4998, 0.9073, 2.1587, 6.1564], count=0
# Epoch 33, time 184.8879, train_loss: 0.4081, test_loss: 0.4362, val_loss: 0.4423, s_norm: 0.0000, pe_norm: 0
# total: [0.5351, 0.9123, 2.4081, 11.0371], count=1
# Epoch 34, time 190.3012, train_loss: 0.4112, test_loss: 0.5464, val_loss: 0.5485, s_norm: 0.0000, pe_norm: 0
# total: [0.4235, 0.7412, 1.6163, 7.4366], count=0
# Epoch 35, time 195.7949, train_loss: 0.3985, test_loss: 0.4120, val_loss: 0.4117, s_norm: 0.0000, pe_norm: 0
# total: [0.6255, 1.5786, 3.2858, 8.0002], count=0
# Epoch 36, time 201.1862, train_loss: 0.4043, test_loss: 0.3852, val_loss: 0.3880, s_norm: 0.0000, pe_norm: 0
# total: [0.5054, 1.1322, 2.5250, 8.5563], count=0
# Epoch 37, time 206.6167, train_loss: 0.3934, test_loss: 0.3758, val_loss: 0.3805, s_norm: 0.0000, pe_norm: 0
# total: [0.5987, 1.3713, 2.7797, 9.8584], count=0
# Epoch 38, time 212.0689, train_loss: 0.3926, test_loss: 0.4284, val_loss: 0.4292, s_norm: 0.0000, pe_norm: 0
# total: [0.5016, 1.2021, 2.4312, 7.2927], count=0
# Epoch 39, time 217.5031, train_loss: 0.3942, test_loss: 0.4523, val_loss: 0.4618, s_norm: 0.0000, pe_norm: 0
# total: [0.5183, 1.2602, 2.3431, 8.9212], count=0
# Epoch 40, time 222.9445, train_loss: 0.3879, test_loss: 0.4224, val_loss: 0.4207, s_norm: 0.0000, pe_norm: 0
# total: [0.6808, 1.1373, 2.7756, 11.2225], count=1
# Epoch 41, time 228.2363, train_loss: 0.3815, test_loss: 0.4824, val_loss: 0.4857, s_norm: 0.0000, pe_norm: 0
# total: [0.7218, 1.5234, 2.9266, 9.5855], count=0
# Epoch 42, time 233.6645, train_loss: 0.3939, test_loss: 0.4392, val_loss: 0.4456, s_norm: 0.0000, pe_norm: 0
# total: [0.7801, 1.4494, 2.7616, 9.3609], count=0
# Epoch 43, time 239.0988, train_loss: 0.3787, test_loss: 0.3969, val_loss: 0.3995, s_norm: 0.0000, pe_norm: 0
# total: [0.6290, 1.2565, 2.9860, 8.4655], count=0
# Epoch 44, time 244.6346, train_loss: 0.3739, test_loss: 0.4168, val_loss: 0.4156, s_norm: 0.0000, pe_norm: 0
# total: [0.5800, 1.8199, 3.4326, 9.2306], count=0
# Epoch 45, time 249.8973, train_loss: 0.3896, test_loss: 0.3865, val_loss: 0.3879, s_norm: 0.0000, pe_norm: 0
# total: [0.4889, 1.1574, 2.6582, 7.6518], count=0
# Epoch 46, time 255.4363, train_loss: 0.3590, test_loss: 0.3971, val_loss: 0.4040, s_norm: 0.0000, pe_norm: 0
# total: [0.6690, 1.3044, 2.7911, 7.8128], count=0
# Epoch 47, time 260.8291, train_loss: 0.3626, test_loss: 0.3572, val_loss: 0.3663, s_norm: 0.0000, pe_norm: 0
# total: [0.7486, 1.6121, 4.0007, 8.4300], count=0
# Epoch 48, time 266.1936, train_loss: 0.3593, test_loss: 0.3739, val_loss: 0.3723, s_norm: 0.0000, pe_norm: 0
# total: [0.8231, 1.8750, 3.5766, 8.2520], count=0
# Epoch 49, time 271.6096, train_loss: 0.3604, test_loss: 0.3768, val_loss: 0.3817, s_norm: 0.0000, pe_norm: 0
# total: [0.6300, 1.5273, 3.3826, 12.2842], count=1
# Epoch 50, time 277.1149, train_loss: 0.3570, test_loss: 0.3502, val_loss: 0.3410, s_norm: 0.0000, pe_norm: 0
# total: [0.7153, 1.4464, 2.9371, 10.5859], count=1
# Epoch 51, time 282.7469, train_loss: 0.3608, test_loss: 0.3818, val_loss: 0.3837, s_norm: 0.0000, pe_norm: 0
# total: [0.7402, 1.3927, 3.0706, 10.4842], count=2
# Epoch 52, time 288.3751, train_loss: 0.3790, test_loss: 0.4023, val_loss: 0.3973, s_norm: 0.0000, pe_norm: 0
# total: [0.7163, 1.9211, 3.1646, 10.0611], count=1
# Epoch 53, time 293.9812, train_loss: 0.3747, test_loss: 0.3633, val_loss: 0.3644, s_norm: 0.0000, pe_norm: 0
# total: [0.9790, 2.0973, 3.3153, 6.7980], count=0
# Epoch 54, time 299.6176, train_loss: 0.3522, test_loss: 0.3750, val_loss: 0.3687, s_norm: 0.0000, pe_norm: 0
# total: [0.5403, 1.3424, 2.9913, 9.8028], count=0
# Epoch 55, time 305.1340, train_loss: 0.3437, test_loss: 0.3559, val_loss: 0.3554, s_norm: 0.0000, pe_norm: 0
# total: [0.6505, 1.4884, 2.9145, 10.7743], count=2
# Epoch 56, time 310.7354, train_loss: 0.3462, test_loss: 0.4289, val_loss: 0.4331, s_norm: 0.0000, pe_norm: 0
# total: [0.7412, 1.8123, 3.8864, 10.6637], count=1
# Epoch 57, time 318.1480, train_loss: 0.3426, test_loss: 0.3551, val_loss: 0.3577, s_norm: 0.0000, pe_norm: 0
# total: [0.9911, 2.3232, 4.2765, 8.5974], count=0
# Epoch 58, time 325.6317, train_loss: 0.3448, test_loss: 0.3766, val_loss: 0.3717, s_norm: 0.0000, pe_norm: 0
# total: [0.6530, 1.4478, 3.2356, 11.1038], count=1
# Epoch 59, time 333.1774, train_loss: 0.3368, test_loss: 0.3613, val_loss: 0.3594, s_norm: 0.0000, pe_norm: 0
# total: [0.8145, 1.8548, 4.3708, 10.1118], count=2
# Epoch 60, time 340.7073, train_loss: 0.3546, test_loss: 0.3702, val_loss: 0.3716, s_norm: 0.0000, pe_norm: 0
# total: [0.6507, 1.4144, 3.4922, 10.5614], count=1
# Epoch 61, time 348.2643, train_loss: 0.3368, test_loss: 0.3659, val_loss: 0.3708, s_norm: 0.0000, pe_norm: 0
# total: [0.8213, 1.9052, 4.2792, 10.5921], count=1
# Epoch 62, time 355.0643, train_loss: 0.3495, test_loss: 0.3595, val_loss: 0.3570, s_norm: 0.0000, pe_norm: 0
# total: [0.8344, 1.8707, 4.2430, 11.0200], count=1
# Epoch 63, time 361.8771, train_loss: 0.3360, test_loss: 0.3949, val_loss: 0.3955, s_norm: 0.0000, pe_norm: 0
# total: [0.7329, 1.4908, 3.3759, 9.4942], count=0
# Epoch 64, time 368.5035, train_loss: 0.3295, test_loss: 0.3889, val_loss: 0.3874, s_norm: 0.0000, pe_norm: 0
# total: [0.7008, 1.3947, 3.3560, 9.4503], count=0
# Epoch 65, time 374.8858, train_loss: 0.3292, test_loss: 0.3301, val_loss: 0.3336, s_norm: 0.0000, pe_norm: 0
# total: [0.7790, 1.4512, 3.4961, 10.5143], count=3
# Epoch 66, time 381.5300, train_loss: 0.3278, test_loss: 0.3389, val_loss: 0.3397, s_norm: 0.0000, pe_norm: 0
# total: [0.7550, 1.2789, 3.1465, 8.5137], count=0
# Epoch 67, time 388.2513, train_loss: 0.3223, test_loss: 0.3462, val_loss: 0.3464, s_norm: 0.0000, pe_norm: 0
# total: [0.8298, 2.1139, 3.9320, 10.6852], count=1
# Epoch 68, time 394.3834, train_loss: 0.3302, test_loss: 0.3211, val_loss: 0.3313, s_norm: 0.0000, pe_norm: 0
# total: [0.6669, 1.8798, 3.4631, 11.1124], count=2
# Epoch 69, time 399.6728, train_loss: 0.3180, test_loss: 0.3307, val_loss: 0.3383, s_norm: 0.0000, pe_norm: 0
# total: [0.8633, 1.8797, 3.5840, 9.6772], count=0
# Epoch 70, time 405.1305, train_loss: 0.3160, test_loss: 0.3242, val_loss: 0.3266, s_norm: 0.0000, pe_norm: 0
# total: [0.7599, 1.8606, 5.1012, 11.6002], count=5
# Epoch 71, time 410.4829, train_loss: 0.3266, test_loss: 0.3121, val_loss: 0.3163, s_norm: 0.0000, pe_norm: 0
# total: [0.8975, 1.9695, 4.6935, 10.0472], count=1
# Epoch 72, time 415.7975, train_loss: 0.3121, test_loss: 0.3648, val_loss: 0.3699, s_norm: 0.0000, pe_norm: 0
# total: [0.7208, 1.3332, 3.1968, 11.4271], count=2
# Epoch 73, time 421.1386, train_loss: 0.3070, test_loss: 0.3148, val_loss: 0.3209, s_norm: 0.0000, pe_norm: 0
# total: [0.6995, 1.6805, 4.8819, 9.4421], count=0
# Epoch 74, time 426.4674, train_loss: 0.3096, test_loss: 0.3103, val_loss: 0.3183, s_norm: 0.0000, pe_norm: 0
# total: [1.0240, 1.9648, 3.9591, 10.2885], count=2
# Epoch 75, time 431.7520, train_loss: 0.3160, test_loss: 0.3346, val_loss: 0.3455, s_norm: 0.0000, pe_norm: 0
# total: [0.7667, 1.7358, 3.9852, 11.4874], count=1
# Epoch 76, time 437.0809, train_loss: 0.3136, test_loss: 0.3086, val_loss: 0.3108, s_norm: 0.0000, pe_norm: 0
# total: [0.7939, 1.9226, 3.7251, 8.3526], count=0
# Epoch 77, time 442.3847, train_loss: 0.2914, test_loss: 0.3255, val_loss: 0.3388, s_norm: 0.0000, pe_norm: 0
# total: [1.0199, 1.6723, 4.0295, 11.7165], count=2
# Epoch 78, time 447.6966, train_loss: 0.3131, test_loss: 0.3355, val_loss: 0.3387, s_norm: 0.0000, pe_norm: 0
# total: [0.9437, 2.3773, 5.0099, 13.5335], count=2
# Epoch 79, time 453.0678, train_loss: 0.3183, test_loss: 0.3220, val_loss: 0.3236, s_norm: 0.0000, pe_norm: 0
# total: [1.0971, 2.1776, 4.2667, 11.1164], count=3
# Epoch 80, time 458.4029, train_loss: 0.3032, test_loss: 0.3651, val_loss: 0.3734, s_norm: 0.0000, pe_norm: 0
# total: [0.7383, 1.9757, 3.8107, 11.7952], count=4
# Epoch 81, time 463.7647, train_loss: 0.2933, test_loss: 0.3277, val_loss: 0.3285, s_norm: 0.0000, pe_norm: 0
# total: [0.7255, 2.1470, 5.6683, 11.3209], count=1
# Epoch 82, time 469.0516, train_loss: 0.3027, test_loss: 0.3027, val_loss: 0.3133, s_norm: 0.0000, pe_norm: 0
# total: [0.7751, 1.6991, 3.8795, 12.1224], count=6
# Epoch 83, time 474.3001, train_loss: 0.2923, test_loss: 0.3303, val_loss: 0.3360, s_norm: 0.0000, pe_norm: 0
# total: [0.8651, 1.7128, 4.7613, 14.3290], count=4
# Epoch 84, time 479.5421, train_loss: 0.3075, test_loss: 0.3259, val_loss: 0.3371, s_norm: 0.0000, pe_norm: 0
# total: [0.8425, 2.0580, 4.4575, 10.8007], count=3
# Epoch 85, time 484.9114, train_loss: 0.3003, test_loss: 0.2944, val_loss: 0.3047, s_norm: 0.0000, pe_norm: 0
# total: [0.6988, 1.8830, 3.6505, 11.4863], count=1
# Epoch 86, time 490.2086, train_loss: 0.2912, test_loss: 0.2959, val_loss: 0.3004, s_norm: 0.0000, pe_norm: 0
# total: [1.0001, 2.0383, 4.3491, 13.9502], count=2
# Epoch 87, time 495.5630, train_loss: 0.2849, test_loss: 0.3089, val_loss: 0.3120, s_norm: 0.0000, pe_norm: 0
# total: [0.9233, 2.2684, 4.3785, 12.1743], count=3
# Epoch 88, time 500.8788, train_loss: 0.2899, test_loss: 0.2907, val_loss: 0.2975, s_norm: 0.0000, pe_norm: 0
# total: [1.0546, 2.3489, 5.0696, 11.1333], count=4
# Epoch 89, time 506.2789, train_loss: 0.2962, test_loss: 0.3032, val_loss: 0.3030, s_norm: 0.0000, pe_norm: 0
# total: [1.0594, 1.8760, 4.3568, 12.9967], count=2
# Epoch 90, time 511.5782, train_loss: 0.2902, test_loss: 0.3030, val_loss: 0.3168, s_norm: 0.0000, pe_norm: 0
# total: [0.8911, 2.2990, 4.5797, 9.3269], count=0
# Epoch 91, time 516.8757, train_loss: 0.2855, test_loss: 0.2960, val_loss: 0.2997, s_norm: 0.0000, pe_norm: 0
# total: [0.8880, 1.8468, 4.8947, 8.9779], count=0
# Epoch 92, time 522.1295, train_loss: 0.2829, test_loss: 0.3162, val_loss: 0.3245, s_norm: 0.0000, pe_norm: 0
# total: [0.9939, 2.3183, 5.0447, 10.8711], count=4
# Epoch 93, time 527.5513, train_loss: 0.2815, test_loss: 0.2995, val_loss: 0.3107, s_norm: 0.0000, pe_norm: 0
# total: [0.9656, 2.2585, 5.1766, 13.0171], count=5
# Epoch 94, time 532.7497, train_loss: 0.2850, test_loss: 0.3819, val_loss: 0.3954, s_norm: 0.0000, pe_norm: 0
# total: [0.9604, 1.9140, 4.8096, 11.6712], count=3
# Epoch 95, time 538.1390, train_loss: 0.2876, test_loss: 0.3274, val_loss: 0.3338, s_norm: 0.0000, pe_norm: 0
# total: [0.8189, 2.0636, 4.6128, 11.4038], count=5
# Epoch 96, time 543.4801, train_loss: 0.2854, test_loss: 0.3521, val_loss: 0.3685, s_norm: 0.0000, pe_norm: 0
# total: [1.1965, 2.3634, 5.1136, 13.7764], count=8
# Epoch 97, time 548.8064, train_loss: 0.2958, test_loss: 0.2968, val_loss: 0.3071, s_norm: 0.0000, pe_norm: 0
# total: [0.7332, 2.1825, 4.5334, 13.0448], count=3
# Epoch 98, time 554.1771, train_loss: 0.2801, test_loss: 0.3352, val_loss: 0.3436, s_norm: 0.0000, pe_norm: 0
# total: [1.1718, 2.1791, 4.7748, 11.8851], count=7
# Epoch 99, time 559.6592, train_loss: 0.2797, test_loss: 0.2950, val_loss: 0.3034, s_norm: 0.0000, pe_norm: 0
# total: [1.0376, 2.2308, 5.5536, 13.2757], count=8
# Epoch 100, time 564.9828, train_loss: 0.2810, test_loss: 0.2862, val_loss: 0.3057, s_norm: 0.0000, pe_norm: 0
# total: [1.1512, 2.8137, 5.3317, 11.5517], count=6
# Epoch 101, time 570.3353, train_loss: 0.2873, test_loss: 0.3020, val_loss: 0.3115, s_norm: 0.0000, pe_norm: 0
# total: [0.9502, 2.0264, 5.5231, 11.5150], count=3
# Epoch 102, time 575.6447, train_loss: 0.2863, test_loss: 0.2789, val_loss: 0.2979, s_norm: 0.0000, pe_norm: 0
# total: [0.8715, 1.8181, 4.2619, 11.5711], count=3
# Epoch 103, time 580.8538, train_loss: 0.2703, test_loss: 0.3394, val_loss: 0.3604, s_norm: 0.0000, pe_norm: 0
# total: [0.8960, 2.3321, 4.9433, 15.9022], count=4
# Epoch 104, time 586.1926, train_loss: 0.2701, test_loss: 0.3243, val_loss: 0.3378, s_norm: 0.0000, pe_norm: 0
# total: [1.0139, 2.2252, 5.5239, 13.2427], count=7
# Epoch 105, time 591.6025, train_loss: 0.2752, test_loss: 0.2774, val_loss: 0.2860, s_norm: 0.0000, pe_norm: 0
# total: [1.0222, 2.0504, 4.4241, 13.0209], count=2
# Epoch 106, time 596.9323, train_loss: 0.2609, test_loss: 0.3030, val_loss: 0.3088, s_norm: 0.0000, pe_norm: 0
# total: [1.1715, 2.3575, 5.9185, 11.7109], count=9
# Epoch 107, time 602.2604, train_loss: 0.2812, test_loss: 0.3109, val_loss: 0.3240, s_norm: 0.0000, pe_norm: 0
# total: [1.0118, 2.3593, 4.7165, 12.9768], count=3
# Epoch 108, time 607.5251, train_loss: 0.2656, test_loss: 0.2894, val_loss: 0.2977, s_norm: 0.0000, pe_norm: 0
# total: [1.0252, 2.5454, 6.3181, 14.2001], count=5
# Epoch 109, time 612.8840, train_loss: 0.2676, test_loss: 0.2808, val_loss: 0.2896, s_norm: 0.0000, pe_norm: 0
# total: [0.9940, 3.3667, 5.9242, 14.6377], count=6
# Epoch 110, time 618.2734, train_loss: 0.2694, test_loss: 0.3915, val_loss: 0.3874, s_norm: 0.0000, pe_norm: 0
# total: [1.0908, 2.0623, 5.6951, 10.9504], count=4
# Epoch 111, time 623.7260, train_loss: 0.2679, test_loss: 0.2883, val_loss: 0.2931, s_norm: 0.0000, pe_norm: 0
# total: [0.9325, 2.2399, 4.7836, 11.8720], count=6
# Epoch 112, time 629.1203, train_loss: 0.2561, test_loss: 0.2669, val_loss: 0.2759, s_norm: 0.0000, pe_norm: 0
# total: [1.3234, 2.7956, 5.9783, 13.0249], count=12
# Epoch 113, time 634.5054, train_loss: 0.2694, test_loss: 0.2929, val_loss: 0.3047, s_norm: 0.0000, pe_norm: 0
# total: [0.9465, 1.9453, 4.6534, 25.6677], count=5
# Epoch 114, time 639.9220, train_loss: 0.2743, test_loss: 0.3230, val_loss: 0.3320, s_norm: 0.0000, pe_norm: 0
# total: [1.0217, 2.1774, 4.6273, 11.4355], count=3
# Epoch 115, time 645.3026, train_loss: 0.2622, test_loss: 0.2907, val_loss: 0.2941, s_norm: 0.0000, pe_norm: 0
# total: [1.1866, 2.5151, 5.4087, 12.8259], count=6
# Epoch 116, time 650.7603, train_loss: 0.2578, test_loss: 0.2827, val_loss: 0.2938, s_norm: 0.0000, pe_norm: 0
# total: [1.1497, 2.8852, 4.6829, 13.3321], count=6
# Epoch 117, time 656.0681, train_loss: 0.2536, test_loss: 0.2933, val_loss: 0.2982, s_norm: 0.0000, pe_norm: 0
# total: [0.8657, 2.9843, 5.0265, 13.4858], count=3
# Epoch 118, time 661.3234, train_loss: 0.2519, test_loss: 0.2612, val_loss: 0.2769, s_norm: 0.0000, pe_norm: 0
# total: [1.3307, 2.6457, 5.1684, 12.5793], count=7
# Epoch 119, time 666.6036, train_loss: 0.2619, test_loss: 0.2735, val_loss: 0.2799, s_norm: 0.0000, pe_norm: 0
# total: [0.8877, 2.3536, 4.9051, 10.2306], count=1
# Epoch 120, time 672.0241, train_loss: 0.2534, test_loss: 0.2784, val_loss: 0.2901, s_norm: 0.0000, pe_norm: 0
# total: [0.9625, 2.4360, 5.6931, 13.8240], count=9
# Epoch 121, time 677.3789, train_loss: 0.2644, test_loss: 0.2838, val_loss: 0.2870, s_norm: 0.0000, pe_norm: 0
# total: [0.8123, 2.1644, 5.4332, 19.7876], count=6
# Epoch 122, time 682.5501, train_loss: 0.2527, test_loss: 0.2680, val_loss: 0.2723, s_norm: 0.0000, pe_norm: 0
# total: [1.2271, 2.4026, 4.5956, 11.3209], count=7
# Epoch 123, time 687.9395, train_loss: 0.2554, test_loss: 0.2643, val_loss: 0.2780, s_norm: 0.0000, pe_norm: 0
# total: [1.0981, 2.8107, 5.8901, 12.5344], count=6
# Epoch 124, time 693.1784, train_loss: 0.2617, test_loss: 0.2784, val_loss: 0.2924, s_norm: 0.0000, pe_norm: 0
# total: [0.9238, 2.5926, 5.5402, 13.2060], count=10
# Epoch 125, time 698.4788, train_loss: 0.2669, test_loss: 0.2739, val_loss: 0.2738, s_norm: 0.0000, pe_norm: 0
# total: [0.9569, 2.4796, 5.0457, 14.1908], count=5
# Epoch 126, time 703.7952, train_loss: 0.2549, test_loss: 0.2869, val_loss: 0.2854, s_norm: 0.0000, pe_norm: 0
# total: [0.7560, 1.8661, 4.7802, 14.9861], count=5
# Epoch 127, time 709.0640, train_loss: 0.2472, test_loss: 0.2773, val_loss: 0.2821, s_norm: 0.0000, pe_norm: 0
# total: [1.4197, 3.3263, 6.0142, 13.3192], count=10
# Epoch 128, time 714.3449, train_loss: 0.2628, test_loss: 0.2718, val_loss: 0.2881, s_norm: 0.0000, pe_norm: 0
# total: [0.9907, 2.6510, 4.5285, 12.6259], count=6
# Epoch 129, time 719.6453, train_loss: 0.2478, test_loss: 0.2662, val_loss: 0.2743, s_norm: 0.0000, pe_norm: 0
# total: [1.0134, 3.1263, 6.3910, 14.2692], count=6
# Epoch 130, time 724.9627, train_loss: 0.2514, test_loss: 0.2769, val_loss: 0.2861, s_norm: 0.0000, pe_norm: 0
# total: [1.3274, 2.8138, 5.7264, 11.9755], count=5
# Epoch 131, time 730.3436, train_loss: 0.2514, test_loss: 0.2669, val_loss: 0.2665, s_norm: 0.0000, pe_norm: 0
# total: [1.4596, 3.3351, 6.4222, 12.3447], count=8
# Epoch 132, time 735.7301, train_loss: 0.2540, test_loss: 0.3336, val_loss: 0.3326, s_norm: 0.0000, pe_norm: 0
# total: [1.0134, 2.3593, 5.5061, 13.7494], count=8
# Epoch 133, time 741.0989, train_loss: 0.2452, test_loss: 0.3038, val_loss: 0.3140, s_norm: 0.0000, pe_norm: 0
# total: [1.1182, 2.7403, 5.5177, 12.2726], count=3
# Epoch 134, time 746.4520, train_loss: 0.2382, test_loss: 0.2540, val_loss: 0.2589, s_norm: 0.0000, pe_norm: 0
# total: [1.1777, 2.7086, 6.4291, 13.0560], count=12
# Epoch 135, time 751.8190, train_loss: 0.2537, test_loss: 0.2601, val_loss: 0.2643, s_norm: 0.0000, pe_norm: 0
# total: [1.5023, 3.2652, 6.9209, 14.9772], count=9
# Epoch 136, time 757.1131, train_loss: 0.2496, test_loss: 0.2539, val_loss: 0.2702, s_norm: 0.0000, pe_norm: 0
# total: [1.0004, 2.9157, 6.7090, 15.0091], count=11
# Epoch 137, time 762.4266, train_loss: 0.2476, test_loss: 0.2607, val_loss: 0.2751, s_norm: 0.0000, pe_norm: 0
# total: [1.1553, 2.3746, 5.5381, 14.8206], count=7
# Epoch 138, time 767.8534, train_loss: 0.2406, test_loss: 0.2777, val_loss: 0.2831, s_norm: 0.0000, pe_norm: 0
# total: [1.0256, 2.3480, 4.7544, 15.2443], count=10
# Epoch 139, time 773.1964, train_loss: 0.2389, test_loss: 0.3112, val_loss: 0.3140, s_norm: 0.0000, pe_norm: 0
# total: [1.3067, 3.0239, 6.6363, 14.1535], count=7
# Epoch 140, time 778.4510, train_loss: 0.2441, test_loss: 0.2788, val_loss: 0.2785, s_norm: 0.0000, pe_norm: 0
# total: [1.0733, 3.0536, 6.5938, 15.0029], count=8
# Epoch 141, time 783.8003, train_loss: 0.2511, test_loss: 0.2625, val_loss: 0.2636, s_norm: 0.0000, pe_norm: 0
# total: [1.4423, 3.1211, 6.4860, 15.4667], count=8
# Epoch 142, time 789.1104, train_loss: 0.2479, test_loss: 0.2799, val_loss: 0.2762, s_norm: 0.0000, pe_norm: 0
# total: [1.1752, 2.8370, 7.1941, 15.8823], count=13
# Epoch 143, time 794.4572, train_loss: 0.2455, test_loss: 0.2616, val_loss: 0.2654, s_norm: 0.0000, pe_norm: 0
# total: [0.9781, 2.1523, 5.0851, 14.0889], count=6
# Epoch 144, time 799.8510, train_loss: 0.2298, test_loss: 0.2629, val_loss: 0.2662, s_norm: 0.0000, pe_norm: 0
# total: [1.4799, 2.8965, 5.8476, 14.6679], count=8
# Epoch 145, time 805.1315, train_loss: 0.2354, test_loss: 0.2691, val_loss: 0.2831, s_norm: 0.0000, pe_norm: 0
# total: [1.2058, 2.5494, 4.8860, 14.9873], count=7
# Epoch 146, time 810.4159, train_loss: 0.2267, test_loss: 0.2457, val_loss: 0.2501, s_norm: 0.0000, pe_norm: 0
# total: [1.2679, 2.6907, 5.7915, 15.0262], count=10
# Epoch 147, time 815.7459, train_loss: 0.2279, test_loss: 0.2362, val_loss: 0.2492, s_norm: 0.0000, pe_norm: 0
# total: [0.8731, 2.5782, 6.6512, 15.2241], count=10
# Epoch 148, time 821.1013, train_loss: 0.2305, test_loss: 0.2452, val_loss: 0.2568, s_norm: 0.0000, pe_norm: 0
# total: [1.0278, 2.9806, 5.9534, 15.6993], count=9
# Epoch 149, time 826.3763, train_loss: 0.2290, test_loss: 0.2451, val_loss: 0.2499, s_norm: 0.0000, pe_norm: 0
# total: [1.1579, 2.4707, 5.6644, 13.5821], count=10
# Epoch 150, time 831.6227, train_loss: 0.2259, test_loss: 0.2534, val_loss: 0.2590, s_norm: 0.0000, pe_norm: 0
# total: [1.7976, 3.5988, 7.0518, 13.8059], count=15
# Epoch 151, time 836.9101, train_loss: 0.2449, test_loss: 0.2460, val_loss: 0.2566, s_norm: 0.0000, pe_norm: 0
# total: [1.0844, 3.1343, 6.3778, 14.1191], count=11
# Epoch 152, time 842.2764, train_loss: 0.2244, test_loss: 0.2992, val_loss: 0.2986, s_norm: 0.0000, pe_norm: 0
# total: [1.1822, 2.6665, 6.5650, 15.8584], count=14
# Epoch 153, time 847.5564, train_loss: 0.2390, test_loss: 0.2571, val_loss: 0.2648, s_norm: 0.0000, pe_norm: 0
# total: [0.9257, 2.9399, 6.0160, 13.0584], count=6
# Epoch 154, time 852.8507, train_loss: 0.2312, test_loss: 0.2456, val_loss: 0.2517, s_norm: 0.0000, pe_norm: 0
# total: [0.9678, 2.7195, 5.3746, 14.9493], count=8
# Epoch 155, time 858.2878, train_loss: 0.2274, test_loss: 0.2863, val_loss: 0.3013, s_norm: 0.0000, pe_norm: 0
# total: [1.3124, 3.3724, 7.4302, 15.1940], count=13
# Epoch 156, time 863.7270, train_loss: 0.2338, test_loss: 0.2420, val_loss: 0.2520, s_norm: 0.0000, pe_norm: 0
# total: [1.1909, 4.1832, 7.1255, 13.3758], count=12
# Epoch 157, time 869.0253, train_loss: 0.2322, test_loss: 0.2460, val_loss: 0.2613, s_norm: 0.0000, pe_norm: 0
# total: [1.0170, 2.7000, 6.4212, 15.7581], count=10
# Epoch 158, time 874.3141, train_loss: 0.2158, test_loss: 0.2395, val_loss: 0.2429, s_norm: 0.0000, pe_norm: 0
# total: [1.3335, 3.1689, 6.9771, 12.8395], count=11
# Epoch 159, time 879.6641, train_loss: 0.2192, test_loss: 0.3447, val_loss: 0.3507, s_norm: 0.0000, pe_norm: 0
# total: [1.1792, 2.9888, 5.6907, 13.8730], count=9
# Epoch 160, time 885.0322, train_loss: 0.2332, test_loss: 0.2967, val_loss: 0.3049, s_norm: 0.0000, pe_norm: 0
# total: [0.9445, 2.4480, 5.9996, 13.7581], count=9
# Epoch 161, time 890.4160, train_loss: 0.2185, test_loss: 0.2782, val_loss: 0.2810, s_norm: 0.0000, pe_norm: 0
# total: [1.6086, 3.6544, 7.8227, 14.7229], count=12
# Epoch 162, time 895.6498, train_loss: 0.2513, test_loss: 0.2622, val_loss: 0.2658, s_norm: 0.0000, pe_norm: 0
# total: [1.0545, 2.4706, 5.3614, 13.2763], count=3
# Epoch 163, time 900.9191, train_loss: 0.2338, test_loss: 0.2916, val_loss: 0.2975, s_norm: 0.0000, pe_norm: 0
# total: [0.9005, 2.2408, 6.4837, 15.6352], count=10
# Epoch 164, time 906.2459, train_loss: 0.2368, test_loss: 0.2547, val_loss: 0.2577, s_norm: 0.0000, pe_norm: 0
# total: [1.6003, 3.7657, 7.0417, 14.6788], count=9
# Epoch 165, time 911.5910, train_loss: 0.2314, test_loss: 0.2738, val_loss: 0.2877, s_norm: 0.0000, pe_norm: 0
# total: [1.6017, 4.3802, 7.5766, 14.8616], count=13
# Epoch 166, time 916.9249, train_loss: 0.2391, test_loss: 0.2768, val_loss: 0.2940, s_norm: 0.0000, pe_norm: 0
# total: [1.2701, 2.9884, 6.1930, 15.0960], count=11
# Epoch 167, time 922.2067, train_loss: 0.2207, test_loss: 0.2392, val_loss: 0.2475, s_norm: 0.0000, pe_norm: 0
# total: [1.1661, 2.2869, 6.3091, 13.5455], count=11
# Epoch 168, time 927.5024, train_loss: 0.2250, test_loss: 0.2583, val_loss: 0.2630, s_norm: 0.0000, pe_norm: 0
# total: [1.9020, 3.9924, 8.2474, 14.6305], count=19
# Epoch 169, time 932.7959, train_loss: 0.2342, test_loss: 0.2792, val_loss: 0.2917, s_norm: 0.0000, pe_norm: 0
# total: [1.6690, 3.2505, 6.8417, 15.2090], count=12
# Epoch 170, time 938.1549, train_loss: 0.2253, test_loss: 0.2520, val_loss: 0.2541, s_norm: 0.0000, pe_norm: 0
# total: [1.1023, 2.9767, 7.1728, 15.5945], count=10
# Epoch 171, time 943.3192, train_loss: 0.2257, test_loss: 0.2330, val_loss: 0.2420, s_norm: 0.0000, pe_norm: 0
# total: [1.0767, 2.8597, 7.8615, 15.2255], count=15
# Epoch 172, time 948.6928, train_loss: 0.2175, test_loss: 0.2615, val_loss: 0.2735, s_norm: 0.0000, pe_norm: 0
# total: [1.1864, 3.0831, 6.6377, 15.0059], count=10
# Epoch 173, time 954.1832, train_loss: 0.2476, test_loss: 0.2400, val_loss: 0.2482, s_norm: 0.0000, pe_norm: 0
# total: [1.3693, 3.3874, 7.2581, 13.9392], count=10
# Epoch 174, time 959.5734, train_loss: 0.2263, test_loss: 0.2321, val_loss: 0.2517, s_norm: 0.0000, pe_norm: 0
# total: [0.9358, 3.5312, 7.2833, 15.2002], count=14
# Epoch 175, time 964.9493, train_loss: 0.2156, test_loss: 0.2374, val_loss: 0.2544, s_norm: 0.0000, pe_norm: 0
# total: [1.1746, 2.7896, 6.2585, 15.0079], count=8
# Epoch 176, time 970.3114, train_loss: 0.2226, test_loss: 0.2707, val_loss: 0.2789, s_norm: 0.0000, pe_norm: 0
# total: [1.2331, 3.3381, 6.4215, 14.3287], count=10
# Epoch 177, time 975.6846, train_loss: 0.2176, test_loss: 0.2330, val_loss: 0.2468, s_norm: 0.0000, pe_norm: 0
# total: [1.0830, 3.8713, 7.2705, 16.1688], count=12
# Epoch 178, time 981.0457, train_loss: 0.2168, test_loss: 0.2325, val_loss: 0.2493, s_norm: 0.0000, pe_norm: 0
# total: [1.4160, 2.9630, 7.5864, 16.4839], count=13
# Epoch 179, time 986.2878, train_loss: 0.2203, test_loss: 0.2320, val_loss: 0.2426, s_norm: 0.0000, pe_norm: 0
# total: [1.2203, 4.0078, 7.5756, 17.0479], count=17
# Epoch 180, time 991.6712, train_loss: 0.2164, test_loss: 0.2324, val_loss: 0.2400, s_norm: 0.0000, pe_norm: 0
# total: [0.9373, 2.8126, 6.9004, 13.3765], count=9
# Epoch 181, time 996.9937, train_loss: 0.2036, test_loss: 0.2659, val_loss: 0.2796, s_norm: 0.0000, pe_norm: 0
# total: [1.4214, 3.6173, 6.4775, 14.4846], count=15
# Epoch 182, time 1002.3360, train_loss: 0.2049, test_loss: 0.2353, val_loss: 0.2487, s_norm: 0.0000, pe_norm: 0
# total: [1.4223, 3.0435, 6.6028, 16.0317], count=12
# Epoch 183, time 1007.6962, train_loss: 0.2088, test_loss: 0.2561, val_loss: 0.2660, s_norm: 0.0000, pe_norm: 0
# total: [0.9428, 2.4064, 5.2804, 14.7098], count=9
# Epoch 184, time 1012.9043, train_loss: 0.2100, test_loss: 0.2341, val_loss: 0.2487, s_norm: 0.0000, pe_norm: 0
# total: [1.3945, 3.7922, 7.6972, 15.4318], count=14
# Epoch 185, time 1018.2208, train_loss: 0.2228, test_loss: 0.2506, val_loss: 0.2671, s_norm: 0.0000, pe_norm: 0
# total: [1.0350, 2.5682, 5.1671, 15.4885], count=6
# Epoch 186, time 1023.5363, train_loss: 0.2138, test_loss: 0.2279, val_loss: 0.2400, s_norm: 0.0000, pe_norm: 0
# total: [1.9488, 4.4165, 8.9334, 15.6797], count=18
# Epoch 187, time 1028.9249, train_loss: 0.2252, test_loss: 0.2343, val_loss: 0.2514, s_norm: 0.0000, pe_norm: 0
# total: [1.3205, 3.6506, 7.3414, 15.9279], count=15
# Epoch 188, time 1034.2314, train_loss: 0.2341, test_loss: 0.2424, val_loss: 0.2493, s_norm: 0.0000, pe_norm: 0
# total: [1.6060, 3.4889, 7.1105, 16.0687], count=9
# Epoch 189, time 1039.5193, train_loss: 0.2164, test_loss: 0.2432, val_loss: 0.2595, s_norm: 0.0000, pe_norm: 0
# total: [1.3259, 3.1964, 8.0703, 14.8323], count=18
# Epoch 190, time 1045.0455, train_loss: 0.2192, test_loss: 0.2344, val_loss: 0.2401, s_norm: 0.0000, pe_norm: 0
# total: [1.3550, 3.5116, 8.5906, 16.3090], count=19
# Epoch 191, time 1050.4091, train_loss: 0.2142, test_loss: 0.2397, val_loss: 0.2540, s_norm: 0.0000, pe_norm: 0
# total: [1.1711, 2.9671, 6.0296, 15.1017], count=12
# Epoch 192, time 1055.7965, train_loss: 0.2011, test_loss: 0.2205, val_loss: 0.2379, s_norm: 0.0000, pe_norm: 0
# total: [1.0784, 2.6895, 7.7661, 14.8550], count=15
# Epoch 193, time 1061.2385, train_loss: 0.2011, test_loss: 0.2173, val_loss: 0.2347, s_norm: 0.0000, pe_norm: 0
# total: [1.3003, 4.1560, 7.1265, 16.2915], count=13
# Epoch 194, time 1066.6573, train_loss: 0.2075, test_loss: 0.2415, val_loss: 0.2533, s_norm: 0.0000, pe_norm: 0
# total: [1.1145, 2.5129, 6.5584, 16.5830], count=7
# Epoch 195, time 1071.9512, train_loss: 0.2127, test_loss: 0.2341, val_loss: 0.2560, s_norm: 0.0000, pe_norm: 0
# total: [0.8676, 3.8015, 7.6549, 16.5268], count=18
# Epoch 196, time 1077.2315, train_loss: 0.2134, test_loss: 0.2434, val_loss: 0.2571, s_norm: 0.0000, pe_norm: 0
# total: [1.2504, 3.8086, 7.6954, 14.5485], count=16
# Epoch 197, time 1082.5908, train_loss: 0.2168, test_loss: 0.2643, val_loss: 0.2788, s_norm: 0.0000, pe_norm: 0
# total: [1.4717, 3.9025, 8.1856, 14.8183], count=18
# Epoch 198, time 1087.9635, train_loss: 0.2260, test_loss: 0.2559, val_loss: 0.2656, s_norm: 0.0000, pe_norm: 0
# total: [1.0763, 2.7585, 7.3516, 15.8314], count=16
# Epoch 199, time 1093.3155, train_loss: 0.2104, test_loss: 0.2265, val_loss: 0.2448, s_norm: 0.0000, pe_norm: 0
# total: [2.0520, 3.8259, 7.3850, 14.9457], count=12
# Epoch 200, time 1098.6108, train_loss: 0.2123, test_loss: 0.2226, val_loss: 0.2343, s_norm: 0.0000, pe_norm: 0
# total: [1.2139, 3.5348, 6.5899, 14.7961], count=12
# Epoch 201, time 1103.9854, train_loss: 0.2041, test_loss: 0.2744, val_loss: 0.2866, s_norm: 0.0000, pe_norm: 0
# total: [0.9794, 3.6700, 8.5271, 15.5740], count=17
# Epoch 202, time 1109.3292, train_loss: 0.2086, test_loss: 0.2324, val_loss: 0.2447, s_norm: 0.0000, pe_norm: 0
# total: [1.6910, 4.1132, 7.7133, 14.6530], count=19
# Epoch 203, time 1114.7205, train_loss: 0.2017, test_loss: 0.2358, val_loss: 0.2596, s_norm: 0.0000, pe_norm: 0
# total: [1.1508, 3.9894, 7.8232, 15.0874], count=14
# Epoch 204, time 1120.0741, train_loss: 0.2146, test_loss: 0.2879, val_loss: 0.2999, s_norm: 0.0000, pe_norm: 0
# total: [1.0088, 2.9621, 6.3014, 15.4335], count=11
# Epoch 205, time 1125.3808, train_loss: 0.2082, test_loss: 0.2493, val_loss: 0.2588, s_norm: 0.0000, pe_norm: 0
# total: [1.3089, 4.6822, 8.8322, 15.3705], count=21
# Epoch 206, time 1130.7290, train_loss: 0.2113, test_loss: 0.2396, val_loss: 0.2550, s_norm: 0.0000, pe_norm: 0
# total: [1.3439, 3.2861, 6.7245, 15.9893], count=15
# Epoch 207, time 1136.0316, train_loss: 0.2042, test_loss: 0.2585, val_loss: 0.2716, s_norm: 0.0000, pe_norm: 0
# total: [1.9267, 4.4359, 8.5218, 15.9349], count=19
# Epoch 208, time 1141.3992, train_loss: 0.2118, test_loss: 0.2428, val_loss: 0.2512, s_norm: 0.0000, pe_norm: 0
# total: [1.3026, 4.2132, 8.5105, 16.1880], count=20
# Epoch 209, time 1146.7703, train_loss: 0.2112, test_loss: 0.2633, val_loss: 0.2661, s_norm: 0.0000, pe_norm: 0
# total: [1.4362, 2.9438, 6.6316, 15.8030], count=13
# Epoch 210, time 1152.1107, train_loss: 0.2041, test_loss: 0.2395, val_loss: 0.2596, s_norm: 0.0000, pe_norm: 0
# total: [1.2057, 3.1639, 9.1202, 16.7428], count=19
# Epoch 211, time 1157.3819, train_loss: 0.2176, test_loss: 0.2253, val_loss: 0.2392, s_norm: 0.0000, pe_norm: 0
# total: [1.2289, 2.6397, 6.8524, 16.1833], count=13
# Epoch 212, time 1162.8720, train_loss: 0.1959, test_loss: 0.2196, val_loss: 0.2291, s_norm: 0.0000, pe_norm: 0
# total: [1.1633, 4.4002, 8.8185, 15.8518], count=19
# Epoch 213, time 1168.2228, train_loss: 0.1989, test_loss: 0.2378, val_loss: 0.2524, s_norm: 0.0000, pe_norm: 0
# total: [1.7133, 3.5254, 8.0063, 17.6472], count=18
# Epoch 214, time 1173.5830, train_loss: 0.2166, test_loss: 0.2311, val_loss: 0.2421, s_norm: 0.0000, pe_norm: 0
# total: [1.7771, 5.1182, 9.7113, 16.6888], count=24
# Epoch 215, time 1178.9835, train_loss: 0.2143, test_loss: 0.2328, val_loss: 0.2416, s_norm: 0.0000, pe_norm: 0
# total: [1.8757, 4.2076, 8.1606, 16.2181], count=18
# Epoch 216, time 1184.3715, train_loss: 0.2077, test_loss: 0.2360, val_loss: 0.2448, s_norm: 0.0000, pe_norm: 0
# total: [1.5684, 4.3114, 9.5525, 15.9426], count=24
# Epoch 217, time 1189.6403, train_loss: 0.2057, test_loss: 0.2294, val_loss: 0.2425, s_norm: 0.0000, pe_norm: 0
# total: [1.1139, 2.7628, 7.5534, 16.5215], count=16
# Epoch 218, time 1195.0333, train_loss: 0.2016, test_loss: 0.2375, val_loss: 0.2428, s_norm: 0.0000, pe_norm: 0
# total: [1.6437, 4.2718, 8.4174, 16.1162], count=17
# Epoch 219, time 1200.4000, train_loss: 0.2041, test_loss: 0.2505, val_loss: 0.2532, s_norm: 0.0000, pe_norm: 0
# total: [1.4300, 4.5129, 8.8762, 16.7613], count=21
# Epoch 220, time 1205.6895, train_loss: 0.2028, test_loss: 0.2268, val_loss: 0.2407, s_norm: 0.0000, pe_norm: 0
# total: [1.2231, 3.5464, 8.9707, 16.4685], count=22
# Epoch 221, time 1211.2790, train_loss: 0.2001, test_loss: 0.2249, val_loss: 0.2322, s_norm: 0.0000, pe_norm: 0
# total: [1.0232, 3.1764, 6.7823, 16.7335], count=17
# Epoch 222, time 1216.5549, train_loss: 0.2012, test_loss: 0.2573, val_loss: 0.2636, s_norm: 0.0000, pe_norm: 0
# total: [1.4544, 4.7083, 8.6474, 16.9358], count=22
# Epoch 223, time 1221.8731, train_loss: 0.2174, test_loss: 0.2803, val_loss: 0.2942, s_norm: 0.0000, pe_norm: 0
# total: [1.5682, 4.0627, 9.0640, 14.7758], count=19
# Epoch 224, time 1227.2136, train_loss: 0.2140, test_loss: 0.2168, val_loss: 0.2302, s_norm: 0.0000, pe_norm: 0
# total: [1.2469, 3.6642, 7.4732, 14.1237], count=12
# Epoch 225, time 1232.5221, train_loss: 0.2074, test_loss: 0.2314, val_loss: 0.2390, s_norm: 0.0000, pe_norm: 0
# total: [1.7963, 3.9290, 7.0704, 16.1108], count=15
# Epoch 226, time 1238.1558, train_loss: 0.2058, test_loss: 0.2732, val_loss: 0.2829, s_norm: 0.0000, pe_norm: 0
# total: [1.4417, 4.5071, 8.0500, 17.6157], count=20
# Epoch 227, time 1245.2335, train_loss: 0.2022, test_loss: 0.2376, val_loss: 0.2576, s_norm: 0.0000, pe_norm: 0
# total: [0.9974, 3.4085, 9.8383, 15.4792], count=25
# Epoch 228, time 1250.5951, train_loss: 0.2040, test_loss: 0.2404, val_loss: 0.2533, s_norm: 0.0000, pe_norm: 0
# total: [1.1725, 3.7475, 7.8301, 16.4670], count=20
# Epoch 229, time 1255.9199, train_loss: 0.2128, test_loss: 0.2576, val_loss: 0.2647, s_norm: 0.0000, pe_norm: 0
# total: [1.3956, 3.8167, 7.8614, 16.7040], count=16
# Epoch 230, time 1261.3008, train_loss: 0.2118, test_loss: 0.2504, val_loss: 0.2600, s_norm: 0.0000, pe_norm: 0
# total: [1.5778, 4.6837, 7.9994, 19.7577], count=18
# Epoch 231, time 1266.5633, train_loss: 0.2118, test_loss: 0.2347, val_loss: 0.2591, s_norm: 0.0000, pe_norm: 0
# total: [1.4072, 3.6425, 6.5031, 17.3475], count=11
# Epoch 232, time 1271.7844, train_loss: 0.2066, test_loss: 0.2347, val_loss: 0.2475, s_norm: 0.0000, pe_norm: 0
# total: [1.5718, 4.0879, 8.0673, 16.5104], count=14
# Epoch 233, time 1279.0466, train_loss: 0.2036, test_loss: 0.2624, val_loss: 0.2690, s_norm: 0.0000, pe_norm: 0
# total: [1.1263, 3.2405, 9.1520, 96.5379], count=20
# Epoch 234, time 1284.6768, train_loss: 0.2088, test_loss: 0.2443, val_loss: 0.2619, s_norm: 0.0000, pe_norm: 0
# total: [0.9856, 3.1034, 6.8939, 16.6977], count=10
# Epoch 235, time 1289.9996, train_loss: 0.2024, test_loss: 0.2295, val_loss: 0.2371, s_norm: 0.0000, pe_norm: 0
# total: [1.3067, 3.7704, 7.0137, 15.9382], count=17
# Epoch 236, time 1295.3637, train_loss: 0.2138, test_loss: 0.2345, val_loss: 0.2485, s_norm: 0.0000, pe_norm: 0
# total: [1.2896, 3.9595, 6.9716, 15.1021], count=15
# Epoch 237, time 1300.7080, train_loss: 0.2050, test_loss: 0.2346, val_loss: 0.2495, s_norm: 0.0000, pe_norm: 0
# total: [1.4782, 3.7334, 7.2699, 16.1861], count=12
# Epoch 238, time 1306.0463, train_loss: 0.1914, test_loss: 0.2312, val_loss: 0.2441, s_norm: 0.0000, pe_norm: 0
# total: [1.2239, 3.5403, 8.3893, 15.8152], count=20
# Epoch 239, time 1311.3709, train_loss: 0.1938, test_loss: 0.2475, val_loss: 0.2587, s_norm: 0.0000, pe_norm: 0
# total: [1.7639, 4.3720, 9.2856, 16.6613], count=23
# Epoch 240, time 1316.7113, train_loss: 0.2079, test_loss: 0.2182, val_loss: 0.2324, s_norm: 0.0000, pe_norm: 0
# total: [1.6272, 5.1918, 9.2135, 17.1032], count=19
# Epoch 241, time 1322.0631, train_loss: 0.1974, test_loss: 0.2286, val_loss: 0.2426, s_norm: 0.0000, pe_norm: 0
# total: [1.3216, 4.1485, 8.5782, 18.4479], count=19
# Epoch 242, time 1327.3968, train_loss: 0.1970, test_loss: 0.2174, val_loss: 0.2261, s_norm: 0.0000, pe_norm: 0
# total: [1.1256, 4.1417, 7.8225, 16.0993], count=17
# Epoch 243, time 1332.7794, train_loss: 0.1797, test_loss: 0.2479, val_loss: 0.2567, s_norm: 0.0000, pe_norm: 0
# total: [1.5077, 3.2566, 8.5909, 17.2061], count=19
# Epoch 244, time 1338.0791, train_loss: 0.1867, test_loss: 0.2272, val_loss: 0.2398, s_norm: 0.0000, pe_norm: 0
# total: [1.3171, 4.3588, 8.0984, 14.9907], count=18
# Epoch 245, time 1343.3638, train_loss: 0.1950, test_loss: 0.2514, val_loss: 0.2692, s_norm: 0.0000, pe_norm: 0
# total: [1.1767, 3.9582, 9.6670, 17.3158], count=23
# Epoch 246, time 1348.7948, train_loss: 0.1968, test_loss: 0.2420, val_loss: 0.2516, s_norm: 0.0000, pe_norm: 0
# total: [1.7721, 4.2633, 8.8970, 17.7787], count=18
# Epoch 247, time 1354.1684, train_loss: 0.2039, test_loss: 0.2893, val_loss: 0.3014, s_norm: 0.0000, pe_norm: 0
# total: [1.0064, 3.0491, 7.4451, 17.1807], count=15
# Epoch 248, time 1359.6436, train_loss: 0.1817, test_loss: 0.2190, val_loss: 0.2317, s_norm: 0.0000, pe_norm: 0
# total: [1.2095, 4.0748, 8.3935, 15.7667], count=17
# Epoch 249, time 1364.9530, train_loss: 0.1918, test_loss: 0.2109, val_loss: 0.2220, s_norm: 0.0000, pe_norm: 0
# total: [2.1616, 5.1347, 9.7234, 16.2258], count=23
# Epoch 250, time 1370.3768, train_loss: 0.1945, test_loss: 0.2805, val_loss: 0.2846, s_norm: 0.0000, pe_norm: 0
# total: [1.7050, 4.4319, 9.7172, 17.5616], count=24
# Epoch 251, time 1375.6573, train_loss: 0.1946, test_loss: 0.2469, val_loss: 0.2553, s_norm: 0.0000, pe_norm: 0
# total: [1.3745, 4.7855, 9.3105, 16.0487], count=21
# Epoch 252, time 1380.8704, train_loss: 0.1871, test_loss: 0.2251, val_loss: 0.2398, s_norm: 0.0000, pe_norm: 0
# total: [1.3504, 3.7199, 8.8366, 17.5708], count=15
# Epoch 253, time 1386.2931, train_loss: 0.1874, test_loss: 0.2162, val_loss: 0.2287, s_norm: 0.0000, pe_norm: 0
# total: [1.2072, 3.8533, 8.9249, 17.1430], count=22
# Epoch 254, time 1391.5971, train_loss: 0.1814, test_loss: 0.2355, val_loss: 0.2463, s_norm: 0.0000, pe_norm: 0
# total: [2.1063, 5.1402, 10.7892, 17.0587], count=28
# Epoch 255, time 1396.9910, train_loss: 0.2042, test_loss: 0.2302, val_loss: 0.2487, s_norm: 0.0000, pe_norm: 0
# total: [1.6592, 5.2813, 10.3986, 15.4420], count=28
# Epoch 256, time 1402.2985, train_loss: 0.1996, test_loss: 0.2554, val_loss: 0.2495, s_norm: 0.0000, pe_norm: 0
# total: [1.3408, 3.3650, 7.2777, 16.8944], count=13
# Epoch 257, time 1407.5807, train_loss: 0.1996, test_loss: 0.2461, val_loss: 0.2545, s_norm: 0.0000, pe_norm: 0
# total: [2.0035, 4.5803, 8.5525, 14.8929], count=15
# Epoch 258, time 1412.9513, train_loss: 0.2110, test_loss: 0.2315, val_loss: 0.2352, s_norm: 0.0000, pe_norm: 0
# total: [1.6233, 3.3529, 9.6501, 16.8391], count=22
# Epoch 259, time 1418.2143, train_loss: 0.2060, test_loss: 0.2493, val_loss: 0.2497, s_norm: 0.0000, pe_norm: 0
# total: [2.4743, 5.4451, 8.8028, 17.0164], count=20
# Epoch 260, time 1423.5665, train_loss: 0.2093, test_loss: 0.2185, val_loss: 0.2266, s_norm: 0.0000, pe_norm: 0
# total: [1.5792, 3.9455, 8.1395, 16.1052], count=14
# Epoch 261, time 1428.8881, train_loss: 0.1937, test_loss: 0.2515, val_loss: 0.2606, s_norm: 0.0000, pe_norm: 0
# total: [1.2651, 3.4010, 9.5923, 17.3110], count=25
# Epoch 262, time 1434.1672, train_loss: 0.2193, test_loss: 0.2283, val_loss: 0.2374, s_norm: 0.0000, pe_norm: 0
# total: [1.3038, 3.5998, 7.3446, 26.2256], count=13
# Epoch 263, time 1439.5151, train_loss: 0.2139, test_loss: 0.2302, val_loss: 0.2368, s_norm: 0.0000, pe_norm: 0
# total: [1.1744, 2.3947, 5.8867, 17.4581], count=14
# Epoch 264, time 1444.8858, train_loss: 0.1897, test_loss: 0.2208, val_loss: 0.2348, s_norm: 0.0000, pe_norm: 0
# total: [1.6972, 4.5550, 8.8032, 16.8711], count=22
# Epoch 265, time 1450.3022, train_loss: 0.1944, test_loss: 0.2653, val_loss: 0.2664, s_norm: 0.0000, pe_norm: 0
# total: [2.2609, 5.2270, 8.6753, 17.5112], count=22
# Epoch 266, time 1455.7101, train_loss: 0.2016, test_loss: 0.2130, val_loss: 0.2275, s_norm: 0.0000, pe_norm: 0
# total: [1.2954, 3.7651, 7.8626, 17.4608], count=19
# Epoch 267, time 1461.0793, train_loss: 0.1819, test_loss: 0.2565, val_loss: 0.2675, s_norm: 0.0000, pe_norm: 0
# total: [1.8771, 4.7085, 10.0437, 17.4507], count=25
# Epoch 268, time 1466.4103, train_loss: 0.1942, test_loss: 0.2139, val_loss: 0.2344, s_norm: 0.0000, pe_norm: 0
# total: [1.6476, 4.1900, 8.2538, 32.2731], count=16
# Epoch 269, time 1471.7596, train_loss: 0.2026, test_loss: 0.2126, val_loss: 0.2254, s_norm: 0.0000, pe_norm: 0
# total: [2.2136, 6.0567, 10.3517, 17.7330], count=27
# Epoch 270, time 1477.0699, train_loss: 0.2077, test_loss: 0.2188, val_loss: 0.2354, s_norm: 0.0000, pe_norm: 0
# total: [1.5705, 4.9733, 8.7118, 16.4063], count=21
# Epoch 271, time 1482.4039, train_loss: 0.1881, test_loss: 0.2325, val_loss: 0.2397, s_norm: 0.0000, pe_norm: 0
# total: [1.6598, 4.3919, 9.2875, 17.2362], count=20
# Epoch 272, time 1487.7594, train_loss: 0.1810, test_loss: 0.2089, val_loss: 0.2127, s_norm: 0.0000, pe_norm: 0
# total: [1.7894, 5.7595, 9.8014, 16.6154], count=24
# Epoch 273, time 1493.1781, train_loss: 0.1841, test_loss: 0.2231, val_loss: 0.2345, s_norm: 0.0000, pe_norm: 0
# total: [1.6974, 4.4644, 8.0223, 17.6311], count=19
# Epoch 274, time 1498.5153, train_loss: 0.1885, test_loss: 0.2323, val_loss: 0.2405, s_norm: 0.0000, pe_norm: 0
# total: [1.4360, 4.3855, 8.2091, 16.2678], count=20
# Epoch 275, time 1503.7848, train_loss: 0.1859, test_loss: 0.2736, val_loss: 0.2861, s_norm: 0.0000, pe_norm: 0
# total: [1.5449, 4.9308, 10.3441, 18.1720], count=29
# Epoch 276, time 1509.1245, train_loss: 0.1890, test_loss: 0.2109, val_loss: 0.2242, s_norm: 0.0000, pe_norm: 0
# total: [1.2704, 4.3516, 9.8521, 18.3569], count=25
# Epoch 277, time 1514.5378, train_loss: 0.1761, test_loss: 0.2030, val_loss: 0.2188, s_norm: 0.0000, pe_norm: 0
# total: [0.9887, 3.5128, 8.7907, 17.9159], count=20
# Epoch 278, time 1519.8647, train_loss: 0.1952, test_loss: 0.2249, val_loss: 0.2358, s_norm: 0.0000, pe_norm: 0
# total: [1.4361, 3.3889, 8.0497, 17.5748], count=19
# Epoch 279, time 1525.0878, train_loss: 0.1812, test_loss: 0.2154, val_loss: 0.2283, s_norm: 0.0000, pe_norm: 0
# total: [1.8742, 4.7420, 8.1699, 17.5376], count=14
# Epoch 280, time 1530.3828, train_loss: 0.1795, test_loss: 0.2333, val_loss: 0.2454, s_norm: 0.0000, pe_norm: 0
# total: [1.4914, 3.4403, 9.1844, 17.2919], count=21
# Epoch 281, time 1535.7413, train_loss: 0.1929, test_loss: 0.2208, val_loss: 0.2369, s_norm: 0.0000, pe_norm: 0
# total: [1.0610, 4.1395, 8.3300, 17.7505], count=21
# Epoch 282, time 1541.0675, train_loss: 0.1922, test_loss: 0.2214, val_loss: 0.2350, s_norm: 0.0000, pe_norm: 0
# total: [1.1870, 5.0012, 9.2865, 17.0581], count=22
# Epoch 283, time 1546.4685, train_loss: 0.1908, test_loss: 0.2287, val_loss: 0.2468, s_norm: 0.0000, pe_norm: 0
# total: [1.1795, 3.6660, 7.6232, 16.2691], count=17
# Epoch 284, time 1551.6917, train_loss: 0.1874, test_loss: 0.2239, val_loss: 0.2283, s_norm: 0.0000, pe_norm: 0
# total: [1.0021, 3.0522, 7.0361, 16.6176], count=19
# Epoch 285, time 1556.9769, train_loss: 0.1917, test_loss: 0.2139, val_loss: 0.2302, s_norm: 0.0000, pe_norm: 0
# total: [1.7889, 3.8188, 6.9516, 18.0245], count=14
# Epoch 286, time 1562.3262, train_loss: 0.1792, test_loss: 0.2103, val_loss: 0.2237, s_norm: 0.0000, pe_norm: 0
# total: [1.2702, 3.4743, 10.2472, 17.4469], count=26
# Epoch 287, time 1567.6853, train_loss: 0.1786, test_loss: 0.2109, val_loss: 0.2208, s_norm: 0.0000, pe_norm: 0
# total: [1.0086, 3.9388, 9.7588, 16.9165], count=23
# Epoch 288, time 1572.9729, train_loss: 0.1879, test_loss: 0.2331, val_loss: 0.2519, s_norm: 0.0000, pe_norm: 0
# total: [1.4424, 6.5621, 11.6392, 18.0658], count=33
# Epoch 289, time 1578.3092, train_loss: 0.1925, test_loss: 0.2232, val_loss: 0.2319, s_norm: 0.0000, pe_norm: 0
# total: [1.3473, 3.9091, 8.4575, 17.9075], count=23
# ...
# total: [5.4400, 12.3171, 17.5262, 27.3577], count=59
# Epoch 1905, time 10206.6825, train_loss: 0.1094, test_loss: 0.1916, val_loss: 0.1919, s_norm: 0.0000, pe_norm: 0
# total: [4.1576, 12.0322, 18.7547, 33.0936], count=56
# Epoch 1906, time 10211.9272, train_loss: 0.1150, test_loss: 0.1867, val_loss: 0.1866, s_norm: 0.0000, pe_norm: 0
# total: [4.2559, 11.3978, 16.6556, 52.5275], count=53
# Epoch 1907, time 10217.2452, train_loss: 0.1042, test_loss: 0.1967, val_loss: 0.1973, s_norm: 0.0000, pe_norm: 0
# total: [2.9429, 9.4968, 16.9957, 34.1018], count=48
# Epoch 1908, time 10222.6461, train_loss: 0.1036, test_loss: 0.1979, val_loss: 0.1988, s_norm: 0.0000, pe_norm: 0
# total: [4.6968, 10.2485, 17.4497, 28.5725], count=52
# Epoch 1909, time 10228.0966, train_loss: 0.1044, test_loss: 0.1884, val_loss: 0.1908, s_norm: 0.0000, pe_norm: 0
# total: [4.6847, 13.7226, 18.4733, 30.8004], count=59
# Epoch 1910, time 10233.5137, train_loss: 0.1073, test_loss: 0.1854, val_loss: 0.1843, s_norm: 0.0000, pe_norm: 0
# total: [3.5327, 12.5839, 18.5898, 29.6956], count=58
# Epoch 1911, time 10238.8311, train_loss: 0.1103, test_loss: 0.1937, val_loss: 0.1969, s_norm: 0.0000, pe_norm: 0
# total: [3.9272, 10.1906, 17.9375, 26.7541], count=50
# Epoch 1912, time 10244.0586, train_loss: 0.1039, test_loss: 0.1937, val_loss: 0.1947, s_norm: 0.0000, pe_norm: 0
# total: [2.8437, 7.6461, 16.9060, 30.3214], count=45
# Epoch 1913, time 10249.3579, train_loss: 0.0916, test_loss: 0.1921, val_loss: 0.1926, s_norm: 0.0000, pe_norm: 0
# total: [4.3653, 10.6521, 17.5494, 28.9690], count=54
# Epoch 1914, time 10254.7247, train_loss: 0.1016, test_loss: 0.1907, val_loss: 0.1968, s_norm: 0.0000, pe_norm: 0
# total: [2.7396, 8.5766, 16.9271, 24.8494], count=47
# Epoch 1915, time 10260.0747, train_loss: 0.1015, test_loss: 0.1884, val_loss: 0.1905, s_norm: 0.0000, pe_norm: 0
# total: [4.0446, 11.5372, 18.4477, 26.4922], count=56
# Epoch 1916, time 10265.5169, train_loss: 0.0994, test_loss: 0.1973, val_loss: 0.2019, s_norm: 0.0000, pe_norm: 0
# total: [2.5695, 7.8200, 16.4622, 24.8302], count=44
# Epoch 1917, time 10270.7995, train_loss: 0.0924, test_loss: 0.1865, val_loss: 0.1878, s_norm: 0.0000, pe_norm: 0
# total: [3.5512, 11.4222, 17.1382, 26.4842], count=54
# Epoch 1918, time 10276.1667, train_loss: 0.1044, test_loss: 0.1902, val_loss: 0.1886, s_norm: 0.0000, pe_norm: 0
# total: [2.0310, 7.4434, 17.3306, 28.7676], count=44
# Epoch 1919, time 10281.4652, train_loss: 0.0981, test_loss: 0.1929, val_loss: 0.1932, s_norm: 0.0000, pe_norm: 0
# total: [2.7655, 8.8591, 16.1136, 40.0470], count=44
# Epoch 1920, time 10286.7941, train_loss: 0.0962, test_loss: 0.1839, val_loss: 0.1843, s_norm: 0.0000, pe_norm: 0
# total: [3.9503, 9.5119, 16.5517, 28.2500], count=46
# Epoch 1921, time 10292.1217, train_loss: 0.0973, test_loss: 0.1909, val_loss: 0.1889, s_norm: 0.0000, pe_norm: 0
# total: [5.2294, 10.1239, 17.2032, 23.8370], count=51
# Epoch 1922, time 10297.3900, train_loss: 0.1063, test_loss: 0.1933, val_loss: 0.1897, s_norm: 0.0000, pe_norm: 0
# total: [3.3578, 11.8970, 18.6009, 31.9717], count=55
# Epoch 1923, time 10302.6891, train_loss: 0.1042, test_loss: 0.1895, val_loss: 0.1887, s_norm: 0.0000, pe_norm: 0
# total: [3.4719, 9.0354, 15.7963, 27.3357], count=46
# Epoch 1924, time 10308.0290, train_loss: 0.0935, test_loss: 0.2000, val_loss: 0.1946, s_norm: 0.0000, pe_norm: 0
# total: [2.5862, 9.9168, 16.0451, 26.2340], count=49
# Epoch 1925, time 10313.3330, train_loss: 0.0915, test_loss: 0.1877, val_loss: 0.1878, s_norm: 0.0000, pe_norm: 0
# total: [3.2328, 10.6853, 17.1710, 27.8584], count=53
# Epoch 1926, time 10318.6475, train_loss: 0.1020, test_loss: 0.1870, val_loss: 0.1877, s_norm: 0.0000, pe_norm: 0
# total: [4.3685, 9.6516, 16.8316, 29.7758], count=49
# Epoch 1927, time 10323.8707, train_loss: 0.1049, test_loss: 0.1899, val_loss: 0.1859, s_norm: 0.0000, pe_norm: 0
# total: [4.0624, 12.6503, 17.9469, 27.3498], count=56
# Epoch 1928, time 10329.2039, train_loss: 0.0961, test_loss: 0.1822, val_loss: 0.1885, s_norm: 0.0000, pe_norm: 0
# total: [3.6573, 10.0700, 15.5312, 27.3959], count=51
# Epoch 1929, time 10334.5461, train_loss: 0.1001, test_loss: 0.1971, val_loss: 0.1981, s_norm: 0.0000, pe_norm: 0
# total: [3.9580, 11.7347, 17.7952, 28.1299], count=53
# Epoch 1930, time 10339.9391, train_loss: 0.1009, test_loss: 0.1915, val_loss: 0.1910, s_norm: 0.0000, pe_norm: 0
# total: [4.5229, 11.2968, 18.2082, 25.3255], count=54
# Epoch 1931, time 10345.2578, train_loss: 0.1031, test_loss: 0.1925, val_loss: 0.1904, s_norm: 0.0000, pe_norm: 0
# total: [3.3815, 10.4793, 17.3122, 28.2622], count=52
# Epoch 1932, time 10350.7024, train_loss: 0.0975, test_loss: 0.1957, val_loss: 0.1916, s_norm: 0.0000, pe_norm: 0
# total: [5.0276, 13.3773, 18.8522, 32.9433], count=58
# Epoch 1933, time 10356.1419, train_loss: 0.1089, test_loss: 0.1871, val_loss: 0.1872, s_norm: 0.0000, pe_norm: 0
# total: [4.8118, 11.0695, 17.9483, 42.6975], count=55
# Epoch 1934, time 10361.4532, train_loss: 0.1066, test_loss: 0.1835, val_loss: 0.1853, s_norm: 0.0000, pe_norm: 0
# total: [3.0779, 9.1898, 16.8344, 31.9582], count=48
# Epoch 1935, time 10366.6666, train_loss: 0.1028, test_loss: 0.1925, val_loss: 0.1971, s_norm: 0.0000, pe_norm: 0
# total: [3.9301, 9.8416, 17.0109, 34.0304], count=49
# Epoch 1936, time 10372.0337, train_loss: 0.1013, test_loss: 0.1999, val_loss: 0.1941, s_norm: 0.0000, pe_norm: 0
# total: [5.7183, 12.1115, 17.5029, 27.7908], count=54
# Epoch 1937, time 10377.3393, train_loss: 0.0949, test_loss: 0.1895, val_loss: 0.1921, s_norm: 0.0000, pe_norm: 0
# total: [3.5121, 10.1462, 16.7694, 26.7408], count=51
# Epoch 1938, time 10382.6213, train_loss: 0.0931, test_loss: 0.1983, val_loss: 0.1967, s_norm: 0.0000, pe_norm: 0
# total: [5.7081, 13.3756, 18.0103, 30.2967], count=57
# Epoch 1939, time 10387.9069, train_loss: 0.1110, test_loss: 0.1928, val_loss: 0.1893, s_norm: 0.0000, pe_norm: 0
# total: [4.9362, 10.9411, 17.0619, 27.2870], count=51
# Epoch 1940, time 10393.2758, train_loss: 0.1084, test_loss: 0.1916, val_loss: 0.1894, s_norm: 0.0000, pe_norm: 0
# total: [4.5892, 10.4797, 18.7763, 41.4752], count=50
# Epoch 1941, time 10398.5875, train_loss: 0.1043, test_loss: 0.1971, val_loss: 0.1945, s_norm: 0.0000, pe_norm: 0
# total: [4.2115, 11.7652, 17.4433, 32.4426], count=55
# Epoch 1942, time 10403.8865, train_loss: 0.1100, test_loss: 0.1943, val_loss: 0.1961, s_norm: 0.0000, pe_norm: 0
# total: [3.5621, 10.4500, 18.1645, 26.8045], count=52
# Epoch 1943, time 10409.1562, train_loss: 0.1039, test_loss: 0.1959, val_loss: 0.1966, s_norm: 0.0000, pe_norm: 0
# total: [4.1202, 9.1333, 18.3129, 24.4360], count=47
# Epoch 1944, time 10414.4084, train_loss: 0.1002, test_loss: 0.1968, val_loss: 0.1960, s_norm: 0.0000, pe_norm: 0
# total: [3.6897, 9.9731, 17.5864, 26.6377], count=50
# Epoch 1945, time 10419.7231, train_loss: 0.0985, test_loss: 0.1921, val_loss: 0.1903, s_norm: 0.0000, pe_norm: 0
# total: [4.8343, 10.2523, 16.5261, 46.1397], count=52
# Epoch 1946, time 10424.9778, train_loss: 0.1021, test_loss: 0.1883, val_loss: 0.1883, s_norm: 0.0000, pe_norm: 0
# total: [4.1116, 11.6207, 17.8376, 33.4364], count=59
# Epoch 1947, time 10430.3657, train_loss: 0.1027, test_loss: 0.1875, val_loss: 0.1896, s_norm: 0.0000, pe_norm: 0
# total: [3.9472, 11.3678, 17.9530, 33.6628], count=57
# Epoch 1948, time 10435.6744, train_loss: 0.1072, test_loss: 0.1938, val_loss: 0.1911, s_norm: 0.0000, pe_norm: 0
# total: [1.9535, 11.0077, 16.9971, 31.2924], count=53
# Epoch 1949, time 10441.0837, train_loss: 0.1012, test_loss: 0.1959, val_loss: 0.1915, s_norm: 0.0000, pe_norm: 0
# total: [3.6842, 10.8159, 15.9957, 50.6154], count=54
# Epoch 1950, time 10446.4893, train_loss: 0.0954, test_loss: 0.1937, val_loss: 0.1934, s_norm: 0.0000, pe_norm: 0
# total: [3.6227, 11.6825, 18.1090, 28.8806], count=52
# Epoch 1951, time 10451.8720, train_loss: 0.1002, test_loss: 0.1983, val_loss: 0.1942, s_norm: 0.0000, pe_norm: 0
# total: [4.2424, 10.6183, 16.9004, 23.0348], count=50
# Epoch 1952, time 10457.2289, train_loss: 0.1031, test_loss: 0.1955, val_loss: 0.1914, s_norm: 0.0000, pe_norm: 0
# total: [4.4692, 11.6773, 18.6004, 42.2196], count=56
# Epoch 1953, time 10462.5809, train_loss: 0.1020, test_loss: 0.1897, val_loss: 0.1881, s_norm: 0.0000, pe_norm: 0
# total: [4.1276, 10.1872, 17.7994, 34.6739], count=50
# Epoch 1954, time 10467.9124, train_loss: 0.0999, test_loss: 0.1936, val_loss: 0.1988, s_norm: 0.0000, pe_norm: 0
# total: [3.5617, 10.4817, 16.2918, 31.0618], count=52
# Epoch 1955, time 10473.2373, train_loss: 0.1018, test_loss: 0.1889, val_loss: 0.1864, s_norm: 0.0000, pe_norm: 0
# total: [3.7287, 11.3235, 17.3733, 23.8931], count=54
# Epoch 1956, time 10478.5780, train_loss: 0.0951, test_loss: 0.1885, val_loss: 0.1816, s_norm: 0.0000, pe_norm: 0
# total: [3.3304, 9.2691, 17.0079, 31.1476], count=45
# Epoch 1957, time 10484.0207, train_loss: 0.0986, test_loss: 0.1899, val_loss: 0.1889, s_norm: 0.0000, pe_norm: 0
# total: [4.1195, 10.5593, 17.3312, 29.0960], count=51
# Epoch 1958, time 10489.4258, train_loss: 0.0970, test_loss: 0.1921, val_loss: 0.1897, s_norm: 0.0000, pe_norm: 0
# total: [3.7290, 10.2732, 17.0314, 33.7188], count=52
# Epoch 1959, time 10494.8258, train_loss: 0.0999, test_loss: 0.1963, val_loss: 0.1973, s_norm: 0.0000, pe_norm: 0
# total: [3.5512, 11.0887, 17.3975, 26.0285], count=53
# Epoch 1960, time 10500.1664, train_loss: 0.0997, test_loss: 0.1909, val_loss: 0.1910, s_norm: 0.0000, pe_norm: 0
# total: [3.8118, 9.6300, 14.4845, 36.8446], count=48
# Epoch 1961, time 10505.4686, train_loss: 0.0952, test_loss: 0.1951, val_loss: 0.1995, s_norm: 0.0000, pe_norm: 0
# total: [5.2951, 13.5883, 19.0221, 29.6497], count=59
# Epoch 1962, time 10510.7941, train_loss: 0.1035, test_loss: 0.1913, val_loss: 0.1943, s_norm: 0.0000, pe_norm: 0
# total: [4.6077, 11.3216, 17.8054, 30.6606], count=55
# Epoch 1963, time 10516.2210, train_loss: 0.1027, test_loss: 0.1881, val_loss: 0.1894, s_norm: 0.0000, pe_norm: 0
# total: [3.0944, 12.7740, 18.2876, 34.1748], count=56
# Epoch 1964, time 10521.5589, train_loss: 0.1037, test_loss: 0.1926, val_loss: 0.1926, s_norm: 0.0000, pe_norm: 0
# total: [3.9055, 12.7483, 18.3844, 33.6218], count=55
# Epoch 1965, time 10526.9826, train_loss: 0.1052, test_loss: 0.1875, val_loss: 0.1822, s_norm: 0.0000, pe_norm: 0
# total: [2.9253, 10.4689, 17.1207, 36.2901], count=51
# Epoch 1966, time 10532.2453, train_loss: 0.0986, test_loss: 0.1908, val_loss: 0.1883, s_norm: 0.0000, pe_norm: 0
# total: [4.7219, 12.3009, 17.9987, 35.3648], count=61
# Epoch 1967, time 10537.5324, train_loss: 0.1037, test_loss: 0.1942, val_loss: 0.1945, s_norm: 0.0000, pe_norm: 0
# total: [4.6517, 11.3604, 18.6147, 28.6511], count=53
# Epoch 1968, time 10542.8321, train_loss: 0.0989, test_loss: 0.1856, val_loss: 0.1838, s_norm: 0.0000, pe_norm: 0
# total: [2.8975, 8.9295, 16.1780, 29.1437], count=44
# Epoch 1969, time 10548.1662, train_loss: 0.0873, test_loss: 0.1937, val_loss: 0.1916, s_norm: 0.0000, pe_norm: 0
# total: [4.5815, 11.9484, 17.3879, 81.2045], count=55
# Epoch 1970, time 10553.5925, train_loss: 0.1025, test_loss: 0.2111, val_loss: 0.2042, s_norm: 0.0000, pe_norm: 0
# total: [2.8736, 10.1659, 18.4076, 31.4005], count=50
# Epoch 1971, time 10558.9534, train_loss: 0.1019, test_loss: 0.1937, val_loss: 0.1847, s_norm: 0.0000, pe_norm: 0
# total: [3.2782, 12.8912, 17.1552, 41.0333], count=56
# Epoch 1972, time 10564.3037, train_loss: 0.0951, test_loss: 0.1861, val_loss: 0.1837, s_norm: 0.0000, pe_norm: 0
# total: [4.0916, 10.7956, 16.6007, 32.3118], count=53
# Epoch 1973, time 10569.6546, train_loss: 0.1016, test_loss: 0.1899, val_loss: 0.1895, s_norm: 0.0000, pe_norm: 0
# total: [5.3095, 13.7513, 18.7084, 62.9934], count=60
# Epoch 1974, time 10574.9747, train_loss: 0.1098, test_loss: 0.1974, val_loss: 0.1935, s_norm: 0.0000, pe_norm: 0
# total: [4.1991, 12.2731, 18.4033, 38.5191], count=55
# Epoch 1975, time 10580.3441, train_loss: 0.1040, test_loss: 0.1962, val_loss: 0.1929, s_norm: 0.0000, pe_norm: 0
# total: [3.5698, 10.4906, 17.8110, 40.1440], count=51
# Epoch 1976, time 10585.6493, train_loss: 0.0957, test_loss: 0.1900, val_loss: 0.1848, s_norm: 0.0000, pe_norm: 0
# total: [3.6150, 10.8728, 16.9298, 26.8074], count=52
# Epoch 1977, time 10591.0105, train_loss: 0.0935, test_loss: 0.1904, val_loss: 0.1872, s_norm: 0.0000, pe_norm: 0
# total: [2.6552, 13.4245, 19.1972, 36.8726], count=56
# Epoch 1978, time 10596.3087, train_loss: 0.1025, test_loss: 0.2033, val_loss: 0.1940, s_norm: 0.0000, pe_norm: 0
# total: [2.8753, 9.8819, 16.2704, 36.6638], count=50
# Epoch 1979, time 10601.5798, train_loss: 0.0944, test_loss: 0.1876, val_loss: 0.1860, s_norm: 0.0000, pe_norm: 0
# total: [2.7966, 10.2601, 17.8956, 60.0978], count=53
# Epoch 1980, time 10606.9734, train_loss: 0.0965, test_loss: 0.1983, val_loss: 0.1906, s_norm: 0.0000, pe_norm: 0
# total: [5.4487, 13.4479, 18.3812, 43.4658], count=58
# Epoch 1981, time 10612.2042, train_loss: 0.1022, test_loss: 0.1889, val_loss: 0.1872, s_norm: 0.0000, pe_norm: 0
# total: [3.5770, 12.1444, 17.5404, 34.8230], count=54
# Epoch 1982, time 10617.5746, train_loss: 0.0972, test_loss: 0.1854, val_loss: 0.1839, s_norm: 0.0000, pe_norm: 0
# total: [3.8435, 10.0385, 17.4602, 39.3270], count=51
# Epoch 1983, time 10622.8859, train_loss: 0.0979, test_loss: 0.1853, val_loss: 0.1847, s_norm: 0.0000, pe_norm: 0
# total: [5.0001, 11.4831, 17.9338, 28.9636], count=56
# Epoch 1984, time 10628.3137, train_loss: 0.0979, test_loss: 0.1823, val_loss: 0.1835, s_norm: 0.0000, pe_norm: 0
# total: [3.8082, 11.0400, 17.7116, 33.8078], count=53
# Epoch 1985, time 10633.6030, train_loss: 0.1003, test_loss: 0.1892, val_loss: 0.1875, s_norm: 0.0000, pe_norm: 0
# total: [3.4931, 10.9275, 17.1614, 32.4343], count=56
# Epoch 1986, time 10638.9911, train_loss: 0.0933, test_loss: 0.1952, val_loss: 0.1988, s_norm: 0.0000, pe_norm: 0
# total: [3.4742, 10.1434, 17.3372, 30.4612], count=50
# Epoch 1987, time 10644.3737, train_loss: 0.0954, test_loss: 0.1925, val_loss: 0.1974, s_norm: 0.0000, pe_norm: 0
# total: [2.6211, 8.7185, 17.3259, 31.8659], count=48
# Epoch 1988, time 10649.6814, train_loss: 0.0961, test_loss: 0.1901, val_loss: 0.1949, s_norm: 0.0000, pe_norm: 0
# total: [3.3121, 8.8077, 18.0605, 26.3866], count=47
# Epoch 1989, time 10654.9622, train_loss: 0.0920, test_loss: 0.1856, val_loss: 0.1855, s_norm: 0.0000, pe_norm: 0
# total: [5.0020, 12.6724, 17.3200, 34.4690], count=57
# Epoch 1990, time 10660.2907, train_loss: 0.1019, test_loss: 0.1937, val_loss: 0.1897, s_norm: 0.0000, pe_norm: 0
# total: [3.6390, 12.1986, 17.5355, 27.4040], count=57
# Epoch 1991, time 10665.5567, train_loss: 0.1061, test_loss: 0.2018, val_loss: 0.2039, s_norm: 0.0000, pe_norm: 0
# total: [6.0377, 11.0469, 17.4986, 52.2273], count=57
# Epoch 1992, time 10670.8980, train_loss: 0.0958, test_loss: 0.1926, val_loss: 0.1909, s_norm: 0.0000, pe_norm: 0
# total: [3.4076, 9.2779, 18.1990, 29.1999], count=48
# Epoch 1993, time 10676.3383, train_loss: 0.0980, test_loss: 0.1895, val_loss: 0.1890, s_norm: 0.0000, pe_norm: 0
# total: [3.8454, 13.5426, 19.7117, 30.1999], count=59
# Epoch 1994, time 10681.6533, train_loss: 0.1111, test_loss: 0.1957, val_loss: 0.1946, s_norm: 0.0000, pe_norm: 0
# total: [2.9866, 11.1064, 16.5803, 35.7561], count=54
# Epoch 1995, time 10686.9681, train_loss: 0.1006, test_loss: 0.1897, val_loss: 0.1909, s_norm: 0.0000, pe_norm: 0
# total: [2.9633, 11.6861, 18.2079, 29.4786], count=54
# Epoch 1996, time 10692.2810, train_loss: 0.0945, test_loss: 0.1912, val_loss: 0.1954, s_norm: 0.0000, pe_norm: 0
# total: [2.8752, 8.6439, 16.6546, 32.6758], count=43
# Epoch 1997, time 10697.7287, train_loss: 0.0954, test_loss: 0.1953, val_loss: 0.1943, s_norm: 0.0000, pe_norm: 0
# total: [3.8759, 12.0508, 18.5560, 40.7769], count=57
# Epoch 1998, time 10703.1133, train_loss: 0.1012, test_loss: 0.1829, val_loss: 0.1867, s_norm: 0.0000, pe_norm: 0
# total: [5.4229, 12.3060, 18.5233, 40.3367], count=62
# Epoch 1999, time 10708.3550, train_loss: 0.1068, test_loss: 0.1910, val_loss: 0.1932, s_norm: 0.0000, pe_norm: 0
# total: [5.0013, 11.9456, 18.3959, 30.9868], count=62
# Epoch 2000, time 10713.6372, train_loss: 0.1090, test_loss: 0.2091, val_loss: 0.2113, s_norm: 0.0000, pe_norm: 0

# %%
for epoch in range(221, 2000):
    optimizer.param_groups[0]['lr'] = 0.001 * 2**(-epoch/800)
    
    epoch_train_loss = run_one_epoch(net, train_loader, None, B_trainset, aug_trainset, True)
    with torch.no_grad(): 
        epoch_test_loss = run_one_epoch(net, test_loader, None, B_testset, aug_testset, False)
        epoch_val_loss = run_one_epoch(net, val_loader, None, B_valset, aug_valset, False)  
    print('Epoch {}, time {:.4f}, train_loss: {:.4f}, test_loss: {:.4f}, val_loss: {:.4f}, s_norm: {:.4f}, pe_norm: {}'.format(epoch, time.time()-start, epoch_train_loss, epoch_test_loss, epoch_val_loss, 0, pe_norm))
    hist_list.append((epoch_train_loss, epoch_test_loss, epoch_val_loss))
    if epoch%100==0:
        torch.save((net.state_dict()), 'zinc_models/zinc_transformerPE_baseline_sd_{}_epoch_{}.pth'.format(seed, epoch))
    if epoch_val_loss < best_val_loss:
        best_net_dict = net.state_dict().copy()

torch.save((best_net_dict,), 'zinc_models/zinc_transformerPE_baseline_sd_{}_best.pth'.format(seed))
loss_dict = torch.load('zinc_models/zinc_transformerPE_baseline_loss_dict.pth')
loss_dict[seed] = hist_list
torch.save(loss_dict, 'zinc_models/zinc_transformerPE_baseline_loss_dict.pth')
